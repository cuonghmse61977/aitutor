# %%
import pandas as pd
import re
import json

from bs4 import BeautifulSoup

def extract_text_from_html(html_content, target_class="kLnDsmZC8c49r2Ntz8LHD"):
    """
    Extracts text content from paragraphs within an HTML string,
    targeting a specific class.

    Args:
        html_content (str): The HTML string to parse.
        target_class (str): The CSS class of the paragraphs to extract.

    Returns:
        str: A string containing the extracted text, joined by newlines.
    """
    if not isinstance(html_content, str): # Check if the input is a string.
        if pd.isna(html_content): # Check for NaN values
            return "" # Return empty string for NaN
        else:
            return str(html_content) # Return the string representation of the number
        
    soup = BeautifulSoup(html_content, 'html.parser')
    
    katex_spans = soup.find_all('span', class_='katex')
    for span in katex_spans:
        annotation = span.find('annotation', encoding='application/x-tex')
        if annotation:
            # Find the mrow tag inside math tag
            math_tag = annotation.find_parent('span', class_='katex-mathml').find('math')
            if math_tag:
                mrow_tag = math_tag.find('mrow')
                if mrow_tag:
                    mrow_tag.decompose()
            
        # Extract text from MathML
        mathml_span = span.find_parent('span', class_='katex-mathml')
        if mathml_span:
            math_tag = mathml_span.find('math')
            if math_tag:
                span.string = math_tag.get_text()
    forms = soup.find_all('form')
    for form in forms:
        dot_space_tag = soup.new_string('. ')
        form.insert_before(dot_space_tag)



    # Modify table content directly and add newlines before tables
    table_tags = soup.find_all('table')
    for table in table_tags:
        new_table_text = "\n"  # Add newline before each table
        for row in table.find_all('tr'):
            row_text = ""
            for cell in row.find_all('td'):
                row_text += cell.get_text(strip=True) + " "  # Add 1 space
            new_table_text += row_text.strip() + "\n"
        table.replace_with(BeautifulSoup(f"<br/><pre>{new_table_text.strip()}</pre>", 'html.parser')) #replace table with preformatted text
    # Replace SVG tags with placeholders
    svg_placeholders = {}
    svg_count = 0
    for svg_tag in soup.find_all('svg'):
        placeholder = f"__SVG_PLACEHOLDER_{svg_count}__"
        svg_placeholders[placeholder] = str(svg_tag)
        svg_tag.replace_with(placeholder)
        svg_count += 1
    
    extracted_text = soup.get_text() #extract from modified soup
    # extracted_text = latex_to_text(extracted_text) #convert latex to text
    extracted_text = format_frequency_table(extracted_text) #remove leading and trailing whitespaces
    extracted_text = remove_markup_text(extracted_text) #remove markup text
    extracted_text = convert_latex_table_to_text(extracted_text) #convert latex tabular to text
    for placeholder, svg_string in svg_placeholders.items():
        extracted_text = extracted_text.replace(placeholder, "")

    print(extracted_text)
    return extracted_text

def latex_to_text(latex_string):
    """Converts LaTeX fraction and parenthesis expressions to plain text."""

    # Replace \left( and \right), \Bigg( and \Bigg) with parentheses
    latex_string = latex_string.replace(r"\left(", "(").replace(r"\right)", ")")
    latex_string = latex_string.replace(r"\Bigg(", "(").replace(r"\Bigg)", ")")

    # Replace \dfrac{numerator}{denominator} and \frac{numerator}{denominator} with numerator/denominator
    latex_string = re.sub(r"\\d?frac\{([^}]*)\}\{([^}]*)\}", r"\1/\2", latex_string)

    # Remove tildes (~) for spaces
    latex_string = latex_string.replace("~", " ")
    latex_string = latex_string.replace(r"\degree", "°")
    latex_string = latex_string.replace(r"\ell", "ℓ")
    latex_string = latex_string.replace(r"\cdots", "…")
    latex_string = latex_string.replace(r"\times", "x")
    latex_string = latex_string.replace(r"\%", "%")
    latex_string = latex_string.replace(r"\lparen", "(")
    latex_string = latex_string.replace(r"\rparen", ")")

    return latex_string

def format_frequency_table(table_data):
    """Formats the given frequency table data into a readable string."""
    lines = table_data.split('\n')
    formatted_lines = []

    for line in lines:
        line = line.strip()
        if line:  # Skip empty lines
            parts = line.replace(r'\quad', ' ').split()  # Split by spaces after replacing \quad
            parts = [part.strip().replace(r'\sim', '~') for part in parts] #remove extra space and replace \sim
            formatted_line = "  ".join(parts) #add double space between each part.
            formatted_lines.append(formatted_line)

    return "\n".join(formatted_lines)

def remove_markup_text(text):
    """Removes \textbf{...} from a string, keeping the text inside."""
    """Removes \text{...} from a LaTeX string, keeping the letter inside."""
    textSub = re.sub(r"\\text\{([^}]*)\}", r"\1", text)
    textSub = re.sub(r"\\textbf\{([^}]*)\}", r"\1", textSub)
    textSub = textSub.replace(r"\raisebox{5pt}{$\underline{  }$}", "-")
    textSub = re.sub(r"\\boxed\{([^}]*)\}", r"\1", textSub)

    return textSub

def convert_latex_table_to_text(html_content):
    """Converts the given LaTeX table HTML to a text table."""

    # Remove LaTeX commands and table structure
    text = re.sub(r"\\def\\arraystretch\{.*?\}", "", html_content) #remove def arraystretch
    text = re.sub(r"\\begin\{array\}\{\|c\|c\|\}\s*\\hline", "", text)
    text = re.sub(r"\\end\{array\}", "", text)
    text = re.sub(r"\\hline", "", text)

    # Replace & with | and \\ with \n
    text = text.replace("&", "|")
    text = text.replace(r"\\", "\n")

    # Remove extra spaces and newlines
    text = "\n".join(line.strip() for line in text.splitlines() if line.strip())

    return text




def convert_csv_html_to_text(file_path, output_path):
    """Reads a CSV file, converts HTML cells to text, and saves to a new CSV."""
    try:
        df = pd.read_csv(file_path)
    except FileNotFoundError:
        print(f"Error: File not found at {file_path}")
        return
    except Exception as e:
        print(f"An unexpected error occurred reading the csv file: {e}")
        return

    for col in df.columns:
        if df[col].dtype == object:  # Check if the column contains strings (potential HTML)
            df[col] = df[col].apply(extract_text_from_html)

    # Handle empty item_id
    for index, row in df.iterrows():
        if pd.isna(row['item_id']) or row['item_id'] == "":
            if index > 0:
                df.at[index, 'question_type' ] = df.at[index - 1, 'question_type']
                df.at[index, 'item_id'] = df.at[index - 1, 'item_id']

    # Handle empty item_description, question_content, explanation by looking up previous matching item_id
    for index, row in df.iterrows():
        if pd.isna(row['item_description']) or pd.isna(row['question_content']) or pd.isna(row['explanation']) or \
            row['item_description'] == "" or row['question_content'] == "" or row['explanation'] == "":
            item_id = row['item_id']
            if pd.notna(item_id):
                previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
                if not previous_rows.empty:
                    previous_row = previous_rows.iloc[-1]  # Get the last matching previous row
                    if pd.isna(row['item_description']) or row['item_description'] == "":
                        df.at[index, 'item_description'] = previous_row['item_description']
                    if pd.isna(row['question_content']) or row['question_content'] == "":
                        df.at[index, 'question_content'] = previous_row['question_content']
                    if pd.isna(row['explanation']) or row['explanation'] == "":
                        df.at[index, 'explanation'] = previous_row['explanation']

            
    try:
         df.to_csv(output_path, index=False, encoding='utf-8-sig') #encoding for excel
         print(f"Successfully converted and saved to {output_path}")
    except Exception as e:
        print(f"Error saving to CSV file: {e}")

def csv_to_json_array_to_file(file_path, output_file_path):
    """Reads a CSV file, converts it to a JSON array, removes records with correct_option = FALSE, and exports to a JSON file."""
    try:
        df = pd.read_csv(file_path)
    except FileNotFoundError:
        return {"error": f"File not found at {file_path}"}
    except Exception as e:
        return {"error": f"An unexpected error occurred reading the csv file: {e}"}

    # Remove records where correct_option is FALSE (case-insensitive)
    df = df[df['correct_option'].astype(str).str.lower() != 'false']
    # Fill empty cells with empty strings
    df = df.fillna("")
    # Convert DataFrame to a list of dictionaries (JSON-like)
    json_array = df.to_dict(orient='records')

    try:
        # Convert the list of dictionaries to a JSON string
        json_string = json.dumps(json_array, ensure_ascii=False, indent=4)

        # Write the JSON string to a file
        with open(output_file_path, 'w', encoding='utf-8') as f:
            f.write(json_string)

        return {"success": f"JSON array exported to {output_file_path}"}

    except Exception as e:
        return {"error": f"An error occurred converting to JSON or writing to file: {e}"}

# %%
# Example usage:
input_file = "file.csv"  # Replace with your input file path
output_file = "output.csv" # Replace with your output file path
output_file_json = "output.json" # Replace with your output file path
convert_csv_html_to_text(input_file, output_file)
csv_to_json_array_to_file(output_file, output_file_json)
# Out:
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# MCQ
# CLOZE_MATH
# MCQ
# CLOZE_MATH
# MCQ
# CLOZE_MATH
# MCQ
# CLOZE_MATH
# MCQ
# CLOZE_MATH
# MCQ
# CLOZE_MATH
# MCQ
# CLOZE_MATH
# MCQ
# CLOZE_MATH
# MCQ
# CLOZE_MATH
# MCQ
# MCQ
# MCQ
# MCQ
# MCQ
# MCQ
# MCQ
# MCQ
# MCQ
# MCQ
# MCQ
# MCQ
# MCQ
# MCQ
# MCQ
# MCQ
# MCQ
# MCQ
# MCQ
# MCQ
# MCQ
# MCQ
# MCQ
# MCQ
# MCQ
# MCQ
# MCQ
# MCQ
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# MCQ
# CLOZE_MATH
# MCQ
# CLOZE_MATH
# MCQ
# CLOZE_MATH
# MCQ
# CLOZE_MATH
# MCQ
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# CLOZE_MATH
# MCQ
# MCQ
# MCQ
# MCQ
# MCQ
# MCQ
# MCQ
# MCQ
# MCQ
# MCQ
# MCQ
# MCQ
# MCQ
# MCQ
# MCQ
# MCQ
# MCQ
# MCQ
# MCQ
# MCQ
# 40939-16362121-renseikai_maths_g7_ch2_t3_se1__-(level_1)
# 40939-16470454-renseikai_maths_g7_ch2_t3_se2__-(level_1)
# 40939-16362261-renseikai_maths_g7_ch2_t3_se3__-(level_1)
# 40939-16362256-renseikai_maths_g7_ch2_t3_se4__-(level_1)
# 40939-16470459-renseikai_maths_g7_ch2_t3_ex3_q1_1__-(level_1)
# 40939-16470474-renseikai_maths_g7_ch2_t3_ex3_q1_3__-(level_1)
# 40939-16470604-renseikai_maths_g7_ch2_t3_ex3_q1_6__-(level_1)
# 40939-16362301-renseikai_maths_g7_ch2_t3_ex3_q1_11__-(level_1)
# 40939-16362316-renseikai_maths_g7_ch2_t3_ex3_q1_12__-(level_1)
# 40939-16362317-renseikai_maths_g7_ch2_t3_ex3_q1_13__-(level_1)
# 40939-16470483-renseikai_maths_g7_ch2_t3_ex3_q1_14__-(level_1)
# 40939-16470585-renseikai_maths_g7_ch2_t3_ex3_q1_15__-(level_1)
# 40939-16470557-renseikai_maths_g7_ch2_t3_ex3_q1_16__-(level_1)
# 40939-16362150-renseikai_maths_g7_ch2_t3_ex3_q1_17__-(level_1)
# 40939-16470494-renseikai_maths_g7_ch2_t3_ex3_q1_18__-(level_1)
# 40939-16470508-renseikai_maths_g7_ch2_t3_ex3_q1_19__-(level_1)
# 40939-16470525-renseikai_maths_g7_ch2_t3_ex3_q1_20__-(level_1)
# 40939-16362178-renseikai_maths_g7_ch2_t3_ex3_q1_21__-(level_1)
# 40939-16362177-renseikai_maths_g7_ch2_t3_ex3_q1_22__-(level_1)
# 40939-16362403-renseikai_maths_g7_ch2_t3_ex3_q1_23__-(level_1)
# 40939-16362099-renseikai_maths_g7_ch2_t3_practa_q2_4__-(level_2)
# 40939-16362196-renseikai_maths_g7_ch2_t3_practa_q2_5__-(level_2)
# 40939-16470530-renseikai_maths_g7_ch2_t3_practa_q2_6__-(level_2)
# 40939-16470542-renseikai_maths_g7_ch2_t3_practa_q2_7__-(level_2)
# 40939-16362244-renseikai_maths_g7_ch2_t3_practa_q2_11__-(level_2)
# 40939-16362051-renseikai_maths_g7_ch2_t3_practa_q2_12__-(level_2)
# 40939-16362053-renseikai_maths_g7_ch2_t3_practa_q2_13__-(level_2)
# 40939-16362046-renseikai_maths_g7_ch2_t3_practa_q2_14__-(level_2)
# 40939-16362072-renseikai_maths_g7_ch2_t3_practa_q2_15__-(level_2)
# 40939-16362346-renseikai_maths_g7_ch2_t3_practa_q2_16__-(level_2)
# 40939-16362330-renseikai_maths_g7_ch2_t3_practa_q2_17__-(level_2)
# 40939-16362354-renseikai_maths_g7_ch2_t3_practa_q2_18__-(level_2)
# 40939-16470548-renseikai_maths_g7_ch2_t3_practb_q1_1__-(level_3)
# 40939-16362353-renseikai_maths_g7_ch2_t3_practb_q1_5__-(level_3)
# 40939-16362360-renseikai_maths_g7_ch2_t3_practb_q3_1__-(level_3)
# 40939-16362392-renseikai_maths_g7_ch2_t3_practb_q3_8__-(level_3)
# 41256-16365026-renseikai_maths_g7_ch2_t1_se1__-(level_1)
# 41256-16365049-renseikai_maths_g7_ch2_t1_se2__-(level_1)
# 41256-16365057-renseikai_maths_g7_ch2_t1_se3__-(level_1)
# 41256-16365032-renseikai_maths_g7_ch2_t1_se4__-(level_1)
# 41256-16365020-renseikai_maths_g7_ch2_t1_ex1_q1_3__-(level_1)
# 41256-16365014-renseikai_maths_g7_ch2_t1_ex1_q1_6__-(level_1)
# 41256-16364999-renseikai_maths_g7_ch2_t1_ex1_q1_11__-(level_1)
# 41256-16365006-renseikai_maths_g7_ch2_t1_ex1_q1_12__-(level_1)
# 41256-16364991-renseikai_maths_g7_ch2_t1_ex1_q1_13__-(level_1)
# 41256-16364990-renseikai_maths_g7_ch2_t1_ex1_q1_14__-(level_1)
# 41256-16364981-renseikai_maths_g7_ch2_t1_ex1_q1_15__-(level_1)
# 41256-16364788-renseikai_maths_g7_ch2_t1_ex1_q1_16__-(level_1)
# 41256-16364760-renseikai_maths_g7_ch2_t1_ex1_q1_17__-(level_1)
# 41256-16364819-renseikai_maths_g7_ch2_t1_ex1_q1_18__-(level_1)
# 41256-16470571-renseikai_maths_g7_ch2_t1_ex1_q1_19__-(level_1)
# 41256-16364809-renseikai_maths_g7_ch2_t1_ex1_q1_20__-(level_1)
# 41256-16364808-renseikai_maths_g7_ch2_t1_ex1_q1_21__-(level_1)
# 41256-16470827-renseikai_maths_g7_ch2_t1_ex1_q1_22__-(level_1)
# 41256-16364838-renseikai_maths_g7_ch2_t1_ex1_q1_23__-(level_1)
# 41256-16471187-renseikai_maths_g7_ch2_t1_ex1_q1_24__-(level_1)
# 41256-16470575-renseikai_maths_g7_ch2_t1_practb_q3_5__-(level_3)
# 41256-16365044-renseikai_maths_g7_ch2_t1_practa_q1_4__-(level_2)
# 41256-16364854-renseikai_maths_g7_ch2_t1_practa_q1_5__-(level_2)
# 41256-16364853-renseikai_maths_g7_ch2_t1_practa_q1_6__-(level_2)
# 41256-16364865-renseikai_maths_g7_ch2_t1_practa_q1_8__-(level_2)
# 41256-16364866-renseikai_maths_g7_ch2_t1_practa_q1_9__-(level_2)
# 41256-16364891-renseikai_maths_g7_ch2_t1_practa_q1_11__-(level_2)
# 41256-16364875-renseikai_maths_g7_ch2_t1_practa_q1_13__-(level_2)
# 41256-16364909-renseikai_maths_g7_ch2_t1_practa_q1_14__-(level_2)
# 41256-16365078-renseikai_maths_g7_ch2_t1_practb_q1_2__-(level_3)
# 41256-16364925-renseikai_maths_g7_ch2_t1_practb_q1_3__-(level_3)
# 41256-16364919-renseikai_maths_g7_ch2_t1_practb_q1_4__-(level_3)
# 41256-16470670-renseikai_maths_g7_ch2_t1_practb_q1_6__-(level_3)
# 39954-16416346-renseikai_maths_g7_ch16_ex5_ct2__-(level_1)
# 39954-16416346-renseikai_maths_g7_ch16_ex5_ct2__-(level_1)
# 39954-16416345-renseikai_maths_g7_ch16_ex5_ct2__-(level_1)
# 39954-16416345-renseikai_maths_g7_ch16_ex5_ct2__-(level_1)
# 39954-16416344-renseikai_maths_g7_ch16_ex5_ct2__-(level_1)
# 39954-16416344-renseikai_maths_g7_ch16_ex5_ct2__-(level_1)
# 39954-16416343-renseikai_maths_g7_ch16_ex5_ct2__-(level_1)
# 39954-16416343-renseikai_maths_g7_ch16_ex5_ct2__-(level_1)
# 39954-16416342-renseikai_maths_g7_ch16_ex5_ct2__-(level_1)
# 39954-16416342-renseikai_maths_g7_ch16_ex5_ct2__-(level_1)
# 39954-16416341-renseikai_maths_g7_ch16_ex5_ct2__-(level_1)
# 39954-16416341-renseikai_maths_g7_ch16_ex5_ct2__-(level_1)
# 39954-16416340-renseikai_maths_g7_ch16_ex5_ct2__-(level_1)
# 39954-16416340-renseikai_maths_g7_ch16_ex5_ct2__-(level_1)
# 39954-16416339-renseikai_maths_g7_ch16_ex5_ct2__-(level_1)
# 39954-16416339-renseikai_maths_g7_ch16_ex5_ct2__-(level_1)
# 39954-16416338-renseikai_maths_g7_ch16_ex5_ct2__-(level_1)
# 39954-16416338-renseikai_maths_g7_ch16_ex5_ct2__-(level_1)
# 39954-16416347-renseikai_maths_g7_ch16_ex5_ct2__-(level_1)
# 39954-16416347-renseikai_maths_g7_ch16_ex5_ct2__-(level_1)
# 40369-16435497-rensekai_maths_g7_ch1_ex1_8_pb_ct6__-(level_3)
# 40369-16435496-rensekai_maths_g7_ch1_ex1_8_pb_ct6__-(level_3)
# 40369-16435495-rensekai_maths_g7_ch1_ex1_8_pb_ct6__-(level_3)
# 40369-16435494-rensekai_maths_g7_ch1_ex1_8_pb_ct6__-(level_3)
# 40369-16435493-rensekai_maths_g7_ch1_ex1_8_pb_ct6__-(level_3)
# 40369-16435502-rensekai_maths_g7_ch1_ex1_8_pb_ct6__-(level_3)
# 40369-16435501-rensekai_maths_g7_ch1_ex1_8_pb_ct6__-(level_3)
# 40369-16435500-rensekai_maths_g7_ch1_ex1_8_pb_ct6__-(level_3)
# 40369-16435499-rensekai_maths_g7_ch1_ex1_8_pb_ct6__-(level_3)
# 40369-16435498-rensekai_maths_g7_ch1_ex1_8_pb_ct6__-(level_3)
# 1007521-16996113-renseikai_maths_g7_ch13_t2_practa_q5_2__-(level_2)
# 1007521-16996107-renseikai_maths_g7_ch13_t2_practa_q5_2__-(level_2)
# 1007521-16996108-renseikai_maths_g7_ch13_t2_practa_q5_2__-(level_2)
# 1007521-16996109-renseikai_maths_g7_ch13_t2_practa_q5_2__-(level_2)
# 1007521-16996110-renseikai_maths_g7_ch13_t2_practa_q5_2__-(level_2)
# 1007521-16996111-renseikai_maths_g7_ch13_t2_practa_q5_2__-(level_2)
# 1007521-16996112-renseikai_maths_g7_ch13_t2_practa_q5_2__-(level_2)
# 1007521-16996249-renseikai_maths_g7_ch13_t2_practa_q5_1__-(level_2)
# 1007521-16996246-renseikai_maths_g7_ch13_t2_practa_q5_1__-(level_2)
# 1007521-16996250-renseikai_maths_g7_ch13_t2_practa_q5_1__-(level_2)
# 1007521-16996252-renseikai_maths_g7_ch13_t2_practa_q5_1__-(level_2)
# 1007521-16996243-renseikai_maths_g7_ch13_t2_practa_q5_1__-(level_2)
# 1007521-16996244-renseikai_maths_g7_ch13_t2_practa_q5_1__-(level_2)
# 1007521-16996245-renseikai_maths_g7_ch13_t2_practa_q5_1__-(level_2)
# 1007521-16996247-renseikai_maths_g7_ch13_t2_practa_q5_1__-(level_2)
# 1007521-16996248-renseikai_maths_g7_ch13_t2_practa_q5_1__-(level_2)
# 1007521-16996251-renseikai_maths_g7_ch13_t2_practa_q5_1__-(level_2)
# 40369-16455776-rensekai_maths_g7_ch1_ex1_8_pa_ct4__-(level_2)
# 40369-16455776-rensekai_maths_g7_ch1_ex1_8_pa_ct4__-(level_2)
# 40369-16455776-rensekai_maths_g7_ch1_ex1_8_pa_ct4__-(level_2)
# 40369-16455774-rensekai_maths_g7_ch1_ex1_8_pa_ct4__-(level_2)
# 40369-16455774-rensekai_maths_g7_ch1_ex1_8_pa_ct4__-(level_2)
# 40369-16455777-rensekai_maths_g7_ch1_ex1_8_pa_ct4__-(level_2)
# 40369-16455777-rensekai_maths_g7_ch1_ex1_8_pa_ct4__-(level_2)
# 40369-16455777-rensekai_maths_g7_ch1_ex1_8_pa_ct4__-(level_2)
# 40369-16455781-rensekai_maths_g7_ch1_ex1_8_pa_ct4__-(level_2)
# 40369-16455781-rensekai_maths_g7_ch1_ex1_8_pa_ct4__-(level_2)
# 40369-16455781-rensekai_maths_g7_ch1_ex1_8_pa_ct4__-(level_2)
# 40369-16455780-rensekai_maths_g7_ch1_ex1_8_pa_ct4__-(level_2)
# 40369-16455780-rensekai_maths_g7_ch1_ex1_8_pa_ct4__-(level_2)
# 40369-16455780-rensekai_maths_g7_ch1_ex1_8_pa_ct4__-(level_2)
# 40369-16455779-rensekai_maths_g7_ch1_ex1_8_pa_ct4__-(level_2)
# 40369-16455779-rensekai_maths_g7_ch1_ex1_8_pa_ct4__-(level_2)
# 40369-16455779-rensekai_maths_g7_ch1_ex1_8_pa_ct4__-(level_2)
# 40369-16455778-rensekai_maths_g7_ch1_ex1_8_pa_ct4__-(level_2)
# 40369-16455778-rensekai_maths_g7_ch1_ex1_8_pa_ct4__-(level_2)
# 40369-16455778-rensekai_maths_g7_ch1_ex1_8_pa_ct4__-(level_2)
# 40369-16455775-rensekai_maths_g7_ch1_ex1_8_pa_ct4__-(level_2)
# 40369-16455775-rensekai_maths_g7_ch1_ex1_8_pa_ct4__-(level_2)
# 40369-16455775-rensekai_maths_g7_ch1_ex1_8_pa_ct4__-(level_2)
# 40369-16455773-rensekai_maths_g7_ch1_ex1_8_pa_ct4__-(level_2)
# 40369-16455773-rensekai_maths_g7_ch1_ex1_8_pa_ct4__-(level_2)
# 40369-16455773-rensekai_maths_g7_ch1_ex1_8_pa_ct4__-(level_2)
# 40369-16455772-rensekai_maths_g7_ch1_ex1_8_pa_ct4__-(level_2)
# 40369-16455772-rensekai_maths_g7_ch1_ex1_8_pa_ct4__-(level_2)
# 40369-16455772-rensekai_maths_g7_ch1_ex1_8_pa_ct4__-(level_2)
# 39951-16405760-rensekai_maths_g7_ch16_ex16_4_ct2__-(level_1)
# 39951-16405760-rensekai_maths_g7_ch16_ex16_4_ct2__-(level_1)
# 39951-16405660-rensekai_maths_g7_ch16_ex16_4_ct2__-(level_1)
# 39951-16405660-rensekai_maths_g7_ch16_ex16_4_ct2__-(level_1)
# 39951-16405759-rensekai_maths_g7_ch16_ex16_4_ct2__-(level_1)
# 39951-16405759-rensekai_maths_g7_ch16_ex16_4_ct2__-(level_1)
# 39951-16405758-rensekai_maths_g7_ch16_ex16_4_ct2__-(level_1)
# 39951-16405758-rensekai_maths_g7_ch16_ex16_4_ct2__-(level_1)
# 39951-16405661-rensekai_maths_g7_ch16_ex16_4_ct2__-(level_1)
# 39951-16405661-rensekai_maths_g7_ch16_ex16_4_ct2__-(level_1)
# 39951-16405659-rensekai_maths_g7_ch16_ex16_4_ct1__-(level_1)
# 39951-16405659-rensekai_maths_g7_ch16_ex16_4_ct1__-(level_1)
# 39951-16405657-rensekai_maths_g7_ch16_ex16_4_ct1__-(level_1)
# 39951-16405657-rensekai_maths_g7_ch16_ex16_4_ct1__-(level_1)
# 39951-16405658-rensekai_maths_g7_ch16_ex16_4_ct1__-(level_1)
# 39951-16405658-rensekai_maths_g7_ch16_ex16_4_ct1__-(level_1)
# 39951-16405656-rensekai_maths_g7_ch16_ex16_4_ct1__-(level_1)
# 39951-16405656-rensekai_maths_g7_ch16_ex16_4_ct1__-(level_1)
# 39951-16405655-rensekai_maths_g7_ch16_ex16_4_ct1__-(level_1)
# 39951-16405655-rensekai_maths_g7_ch16_ex16_4_ct1__-(level_1)
# 39956-16406074-rensekai_maths_g7_ch16_ex16_6_ct1__-(level_2)
# 39956-16406074-rensekai_maths_g7_ch16_ex16_6_ct1__-(level_2)
# 39956-16406074-rensekai_maths_g7_ch16_ex16_6_ct1__-(level_2)
# 39956-16406075-rensekai_maths_g7_ch16_ex16_6_ct1__-(level_2)
# 39956-16406075-rensekai_maths_g7_ch16_ex16_6_ct1__-(level_2)
# 39956-16406075-rensekai_maths_g7_ch16_ex16_6_ct1__-(level_2)
# 39956-16406073-rensekai_maths_g7_ch16_ex16_6_ct1__-(level_2)
# 39956-16406073-rensekai_maths_g7_ch16_ex16_6_ct1__-(level_2)
# 39956-16406073-rensekai_maths_g7_ch16_ex16_6_ct1__-(level_2)
# 39956-16406077-rensekai_maths_g7_ch16_ex16_6_ct1__-(level_2)
# 39956-16406077-rensekai_maths_g7_ch16_ex16_6_ct1__-(level_2)
# 39956-16406077-rensekai_maths_g7_ch16_ex16_6_ct1__-(level_2)
# 39956-16406076-rensekai_maths_g7_ch16_ex16_6_ct1__-(level_2)
# 39956-16406076-rensekai_maths_g7_ch16_ex16_6_ct1__-(level_2)
# 39956-16406076-rensekai_maths_g7_ch16_ex16_6_ct1__-(level_2)
# 40369-16455691-rensekai_maths_g7_ch1_ex1_8_ct3__-(level_1)
# 40369-16455690-rensekai_maths_g7_ch1_ex1_8_ct3__-(level_1)
# 40369-16455695-rensekai_maths_g7_ch1_ex1_8_ct3__-(level_1)
# 40369-16455694-rensekai_maths_g7_ch1_ex1_8_ct3__-(level_1)
# 40369-16455693-rensekai_maths_g7_ch1_ex1_8_ct3__-(level_1)
# 40369-16455692-rensekai_maths_g7_ch1_ex1_8_ct3__-(level_1)
# 40369-16455696-rensekai_maths_g7_ch1_ex1_8_ct3__-(level_1)
# 40369-16455689-rensekai_maths_g7_ch1_ex1_8_ct3__-(level_1)
# 40369-16455688-rensekai_maths_g7_ch1_ex1_8_ct3__-(level_1)
# 40369-16455687-rensekai_maths_g7_ch1_ex1_8_ct3__-(level_1)
# 40369-16330993-rensekai_maths_g7_ch1_ex1_8_ct2__-(level_1)
# 40369-16330985-rensekai_maths_g7_ch1_ex1_8_ct2__-(level_1)
# 40369-16331000-rensekai_maths_g7_ch1_ex1_8_ct2__-(level_1)
# 40369-16331017-rensekai_maths_g7_ch1_ex1_8_ct2__-(level_1)
# 40369-16330980-rensekai_maths_g7_ch1_ex1_8_ct2__-(level_1)
# 40369-16330979-rensekai_maths_g7_ch1_ex1_8_ct2__-(level_1)
# 40369-16331010-rensekai_maths_g7_ch1_ex1_8_ct2__-(level_1)
# 40369-16331006-rensekai_maths_g7_ch1_ex1_8_ct2__-(level_1)
# 40369-16330989-rensekai_maths_g7_ch1_ex1_8_ct2__-(level_1)
# 40369-16330984-rensekai_maths_g7_ch1_ex1_8_ct2__-(level_1)
# 次の減法を加法に直して計算しなさい。(+7)-(+1)
# 次の減法を加法に直して計算しなさい。(-9)-(+1)
# 次の減法を加法に直して計算しなさい。(+9)-(-1)
# 次の減法を加法に直して計算しなさい。(-4)-(-3)
# 次の減法を加法に直して計算しなさい。(+7)-(+9)
# 次の減法を加法に直して計算しなさい。(+8)-(+8)
# 次の減法を加法に直して計算しなさい。(-1)-(-7)
# 次の減法を加法に直して計算しなさい。0-(+3)
# 次の減法を加法に直して計算しなさい。0-(-1)
# 次の減法を加法に直して計算しなさい。(+0.4)-(+0.1)
# 次の減法を加法に直して計算しなさい。(-1.9)-(-2.8)
# 次の減法を加法に直して計算しなさい。(+2.4)-(-1.1)
# 次の減法を加法に直して計算しなさい。(+0.1)-(+0.46)
# 次の減法を加法に直して計算しなさい。(-0.45)-(+0.1)
# 次の減法を加法に直して計算しなさい。(-1.78)-(-4.8)
# 次の減法を加法に直して計算しなさい。\left(+\dfrac{4}{9}\right)-\left(-\dfrac{7}{9}\right)
# 次の減法を加法に直して計算しなさい。\left(-\dfrac{18}{7}\right)-\left(+\dfrac{20}{7}\right)
# 次の減法を加法に直して計算しなさい。\left(-\dfrac{3}{5}\right)-\left(+\dfrac{2}{7}\right)
# 次の減法を加法に直して計算しなさい。\left(+\dfrac{3}{2}\right)-\left(-\dfrac{2}{3}\right)
# 次の減法を加法に直して計算しなさい。\left(-\dfrac{13}{15}\right)-\left(-\dfrac{1}{6}\right)
# 次の計算をしなさい。(+2)-(-2)
# 次の計算をしなさい。(-1)-(+1)
# 次の計算をしなさい。(-6)-(-6)
# 次の計算をしなさい。(-8)-0
# 次の計算をしなさい。(+3)-(-35)
# 次の計算をしなさい。(+2)-(+22)
# 次の計算をしなさい。(+26)-(-14)
# 次の計算をしなさい。(-11)-(-18)
# 次の計算をしなさい。(-32)-(+35)
# 次の計算をしなさい。(+17)-(+42)
# 次の計算をしなさい。(+18)-(-31)
# 次の計算をしなさい。(-51)-(-13)
# 次の計算をしなさい。(-5.2)-(-4.5)
# 次の計算をしなさい。\left(-\dfrac{20}{9}\right)-\left(-\dfrac{5}{9}\right)
# 次の計算をしなさい。(-1.1)-(-0.47)
# 次の計算をしなさい。(-0.29)-(-2.6)
# 次の計算をしなさい。(+~5)  +  (+~1)
# 次の計算をしなさい。(-~2)  +  (-~8)
# 次の計算をしなさい。(+~8)  +  (-~1)
# 次の計算をしなさい。(+~4)  +  (-~6)
# 次の計算をしなさい。(+~2)  +  (+~2)
# 次の計算をしなさい。(-~6)  +  (+~3)
# 次の計算をしなさい。0  +  (+~2)
# 次の計算をしなさい。0  +  (-~2)
# 次の計算をしなさい。(+~0.5)  +  (-~0.8)
# 次の計算をしなさい。(-~0.2)  +  (-~0.9)
# 次の計算をしなさい。(+~2.3)  +  (-~0.4)
# 次の計算をしなさい。(+~1.2)  +  (+~3.4)
# 次の計算をしなさい。(-~3.6)  +  (+~2.8)
# 次の計算をしなさい。(-~2.6)  +  (-~3.8)
# 次の計算をしなさい。\Bigg(-\dfrac{1}{9}\Bigg)  +  \Bigg(-\dfrac{8}{9}\Bigg)
# 次の計算をしなさい。\Bigg(-~\dfrac{5}{4}\Bigg)  +  \Bigg(+~\dfrac{3}{4}\Bigg)
# 次の計算をしなさい。\Bigg(+~\dfrac{1}{3}\Bigg)  +  \Bigg(-~\dfrac{3}{4}\Bigg)
# 次の計算をしなさい。\Bigg(+~\dfrac{8}{3}\Bigg)  +  \Bigg(-~\dfrac{7}{6}\Bigg)
# 次の計算をしなさい。\Bigg(-~\dfrac{1}{4}\Bigg)  +  \Bigg(-~\dfrac{7}{12}\Bigg)
# 次の計算をしなさい。\Bigg(-~\dfrac{4}{3}\Bigg)  +  \Bigg(+~\dfrac{8}{15}\Bigg)
# 次の計算をしなさい。\Bigg(-~\dfrac{13}{4}\Bigg)  +  \Bigg(+~\dfrac{7}{3}\Bigg)
# 次の計算をしなさい。(+~6)  +  (-~6)
# 次の計算をしなさい。(+~7)  +  (+~7)
# 次の計算をしなさい。(-~3)  +  (-~3)
# 次の計算をしなさい。(-~5)  +  0
# 次の計算をしなさい。0  +  (-~5)
# 次の計算をしなさい。(+~18)  +  (-~1)
# 次の計算をしなさい。(-~18)  +  (-~21)
# 次の計算をしなさい。(-~18)  +  (+~41)
# 次の計算をしなさい。(-~0.14)  +  (+~0.3)
# 次の計算をしなさい。(-~0.25)  +  (+~0.7)
# 次の計算をしなさい。\Bigg(+~\dfrac{37}{6}\Bigg)  +  \Bigg(-~\dfrac{19}{6}\Bigg)
# 次の計算をしなさい。\Bigg(+~\dfrac{5}{18}\Bigg)  +  \Bigg(-~\dfrac{2}{15}\Bigg)
# 次の表は,~~50人の生徒の100m走の記録について,~~累積度数および累積相対度数を調べた結果をまとめたものである。~~階級(秒)  ~~累積度数(人)  ~~累積相対度数
# ~以上~~~~~未満  ~~~
# 13.0~~~13.5  ~~  3  ~~  0.060
# 13.5~~~14.0  ~~  11  ~~  0.220
# 14.0~~~14.5  ~~  21  ~~  0.420
# 14.5~~~15.0  ~~  24  ~~  0.480
# 15.0~~~15.5  ~~  35  ~~  0.700
# 15.5~~~16.0  ~~  41  ~~  0.820
# 16.0~~~16.5  ~~  50  ~~  1.000
# 次の表は,~~40人の生徒の100m走の記録について,~~累積度数および累積相対度数を調べた結果をまとめたものである。~~階級(秒)  ~~累積度数(人)  ~~累積相対度数
# ~以上~~~~~未満  ~~~
# 13.0~~~13.5  ~~  1  ~~  0.025
# 13.5~~~14.0  ~~  10  ~~  0.250
# 14.0~~~14.5  ~~  17  ~~  0.425
# 14.5~~~15.0  ~~  29  ~~  0.725
# 15.0~~~15.5  ~~  33  ~~  0.825
# 15.5~~~16.0  ~~  39  ~~  0.975
# 16.0~~~16.5  ~~  40  ~~  1.000
# 次の表は,~~50人の生徒の100m走の記録について,~~累積度数および累積相対度数を調べた結果をまとめたものである。~~階級(秒)  ~~累積度数(人)  ~~累積相対度数
# ~以上~~~~~未満  ~~~
# 13.0~~~13.5  ~~  2  ~~  0.040
# 13.5~~~14.0  ~~  10  ~~  0.200
# 14.0~~~14.5  ~~  18  ~~  0.360
# 14.5~~~15.0  ~~  20  ~~  0.400
# 15.0~~~15.5  ~~  39  ~~  0.780
# 15.5~~~16.0  ~~  43  ~~  0.860
# 16.0~~~16.5  ~~  50  ~~  1.000
# 次の表は,~~50人の生徒の100m走の記録について,~~累積度数および累積相対度数を調べた結果をまとめたものである。~~階級(秒)  ~~累積度数(人)  ~~累積相対度数
# ~以上~~~~~未満  ~~~
# 13.0~~~13.5  ~~  3  ~~  0.060
# 13.5~~~14.0  ~~  10  ~~  0.200
# 14.0~~~14.5  ~~  25  ~~  0.500
# 14.5~~~15.0  ~~  41  ~~  0.820
# 15.0~~~15.5  ~~  45  ~~  0.900
# 15.5~~~16.0  ~~  48  ~~  0.960
# 16.0~~~16.5  ~~  50  ~~  1.000
# 次の表は,~~40人の生徒の100m走の記録について,~~累積度数および累積相対度数を調べた結果をまとめたものである。~~階級(秒)  ~~累積度数(人)  ~~累積相対度数
# ~以上~~~~~未満  ~~~
# 13.0~~~13.5  ~~  3  ~~  0.075
# 13.5~~~14.0  ~~  10  ~~  0.250
# 14.0~~~14.5  ~~  15  ~~  0.375
# 14.5~~~15.0  ~~  25  ~~  0.625
# 15.0~~~15.5  ~~  26  ~~  0.650
# 15.5~~~16.0  ~~  29  ~~  0.725
# 16.0~~~16.5  ~~  40  ~~  1.000
# 次の表は,~~50人の生徒の100m走の記録について,~~累積度数および累積相対度数を調べた結果をまとめたものである。~~階級(秒)  ~~累積度数(人)  ~~累積相対度数
# ~以上~~~~~未満  ~~~
# 13.0~~~13.5  ~~  2  ~~  0.040
# 13.5~~~14.0  ~~  10  ~~  0.200
# 14.0~~~14.5  ~~  12  ~~  0.240
# 14.5~~~15.0  ~~  20  ~~  0.400
# 15.0~~~15.5  ~~  27  ~~  0.540
# 15.5~~~16.0  ~~  40  ~~  0.800
# 16.0~~~16.5  ~~  50  ~~  1.000
# 次の表は,~~40人の生徒の100m走の記録について,~~累積度数および累積相対度数を調べた結果をまとめたものである。~~階級(秒)  ~~累積度数(人)  ~~累積相対度数
# ~以上~~~~~未満  ~~~
# 13.0~~~13.5  ~~  3  ~~  0.075
# 13.5~~~14.0  ~~  12  ~~  0.300
# 14.0~~~14.5  ~~  30  ~~  0.750
# 14.5~~~15.0  ~~  32  ~~  0.800
# 15.0~~~15.5  ~~  34  ~~  0.850
# 15.5~~~16.0  ~~  39  ~~  0.975
# 16.0~~~16.5  ~~  40  ~~  1.000
# 次の表は,~~40人の生徒の100m走の記録について,~~累積度数および累積相対度数を調べた結果をまとめたものである。~~階級(秒)  ~~累積度数(人)  ~~累積相対度数
# ~以上~~~~~未満  ~~~
# 13.0~~~13.5  ~~  3  ~~  0.075
# 13.5~~~14.0  ~~  10  ~~  0.250
# 14.0~~~14.5  ~~  21  ~~  0.525
# 14.5~~~15.0  ~~  24  ~~  0.600
# 15.0~~~15.5  ~~  33  ~~  0.825
# 15.5~~~16.0  ~~  38  ~~  0.950
# 16.0~~~16.5  ~~  40  ~~  1.000
# 次の表は,~~50人の生徒の100m走の記録について,~~累積度数および累積相対度数を調べた結果をまとめたものである。~~階級(秒)  ~~累積度数(人)  ~~累積相対度数
# ~以上~~~~~未満  ~~~
# 13.0~~~13.5  ~~  4  ~~  0.080
# 13.5~~~14.0  ~~  12  ~~  0.240
# 14.0~~~14.5  ~~  14  ~~  0.280
# 14.5~~~15.0  ~~  28  ~~  0.560
# 15.0~~~15.5  ~~  31  ~~  0.620
# 15.5~~~16.0  ~~  44  ~~  0.880
# 16.0~~~16.5  ~~  50  ~~  1.000
# 次の表は,~~50人の生徒の100m走の記録について,~~累積度数および累積相対度数を調べた結果をまとめたものである。~~階級(秒)  ~~累積度数(人)  ~~累積相対度数
# ~以上~~~~~未満  ~~~
# 13.0~~~13.5  ~~  3  ~~  0.060
# 13.5~~~14.0  ~~  10  ~~  0.200
# 14.0~~~14.5  ~~  21  ~~  0.420
# 14.5~~~15.0  ~~  22  ~~  0.440
# 15.0~~~15.5  ~~  26  ~~  0.520
# 15.5~~~16.0  ~~  33  ~~  0.660
# 16.0~~~16.5  ~~  50  ~~  1.000
# 次の数の絶対値を答えなさい。
# 次の数の絶対値を答えなさい。
# 次の数の絶対値を答えなさい。
# 次の数の絶対値を答えなさい。
# 次の数の絶対値を答えなさい。
# 次の数の絶対値を答えなさい。
# 次の数の絶対値を答えなさい。
# 次の数の絶対値を答えなさい。
# 次の数の絶対値を答えなさい。
# 次の数の絶対値を答えなさい。
# 次の表は,~~190人の生徒の身長を測定した結果を累積度数分布表にまとめたものである。    階級(cm)  |  累積度数(人)
# 以上  ~~~~  未満  |
# 140~  ~  ~145  |  11
# 145~  ~  ~  150  |  32
# 150~  ~  ~155  |  56
# 155~  ~  ~160  |  126
# 160~  ~  ~  165  |  148
# 165~  ~  ~  170  |  167
# 170~  ~  ~  175  |  190
# 次の表は,~~200人の生徒の身長を測定した結果を累積度数分布表にまとめたものである。    階級(cm)  |  累積度数(人)
# 以上  ~~~~  未満  |
# 140~  ~  ~145  |  15
# 145~  ~  ~  150  |  36
# 150~  ~  ~155  |  76
# 155~  ~  ~160  |  121
# 160~  ~  ~  165  |  158
# 165~  ~  ~  170  |  182
# 170~  ~  ~  175  |  200
# 次の表は,~~180人の生徒の身長を測定した結果を累積度数分布表にまとめたものである。    階級(cm)  |  累積度数(人)
# 以上  ~~~~  未満  |
# 120~  ~  ~125  |  17
# 125~  ~  ~  130  |  26
# 130~  ~  ~135  |  66
# 135~  ~  ~140  |  113
# 140~  ~  ~  145  |  162
# 145~  ~  ~  150  |  178
# 150~  ~  ~  155  |  180
# 次の表は,~~200人の生徒の身長を測定した結果を累積度数分布表にまとめたものである。    階級(cm)  |  累積度数(人)
# 以上  ~~~~  未満  |
# 150~  ~  ~155  |  13
# 155~  ~  ~  160  |  29
# 160~  ~  ~165  |  79
# 165~  ~  ~170  |  116
# 170~  ~  ~  175  |  137
# 175~  ~  ~  180  |  172
# 180~  ~  ~  185  |  200
# 次の表は,~~200人の生徒の身長を測定した結果を累積度数分布表にまとめたものである。    階級(cm)  |  累積度数(人)
# 以上  ~~~~  未満  |
# 130~  ~  ~135  |  25
# 135~  ~  ~  140  |  36
# 140~  ~  ~145  |  86
# 145~  ~  ~150  |  131
# 150~  ~  ~  155  |  158
# 155~  ~  ~  160  |  186
# 160~  ~  ~  165  |  200
# 次の表は,~~67人の生徒の垂直とびの記録を度数分布表にまとめたものである。
# 次の表は,~~40人の生徒の垂直とびの記録を度数分布表にまとめたものである。
# 次の表は,~~60人の生徒の垂直とびの記録を度数分布表にまとめたものである。
# 次の表は,~~50人の生徒の垂直とびの記録を度数分布表にまとめたものである。
# 次の表は,~~50人の生徒の垂直とびの記録を度数分布表にまとめたものである。
# ペットボトルのキャップをくり返し投げ,~~表向きになった回数を100回ごとに記録したところ,~~次の表のようになった。投げた回数(回)  100  200  300  400  500
# 表向きになった回数(回)  15  26  55  76  95
# 表向きになる相刘度数  0.15  0.13  ア  イ  ウ
# ペットボトルのキャップをくり返し投げ,~~表向きになった回数を100回ごとに記録したところ,~~次の表のようになった。投げた回数(回)  100  200  300  400  500
# 表向きになった回数(回)  25  52  81  112  140
# 表向きになる相刘度数  0.25  0.26  ア  イ  ウ
# ペットボトルのキャップをくり返し投げ,~~表向きになった回数を100回ごとに記録したところ,~~次の表のようになった。投げた回数(回)  100  200  300  400  500
# 表向きになった回数(回)  45  82  129  169  210
# 表向きになる相刘度数  0.45  0.41  ア  イ  ウ
# ペットボトルのキャップをくり返し投げ,~~表向きになった回数を100回ごとに記録したところ,~~次の表のようになった。投げた回数(回)  100  200  300  400  500
# 表向きになった回数(回)  55  108  159  208  260
# 表向きになる相刘度数  0.55  0.54  ア  イ  ウ
# ペットボトルのキャップをくり返し投げ,~~表向きになった回数を100回ごとに記録したところ,~~次の表のようになった。投げた回数(回)  100  200  300  400  500
# 表向きになった回数(回)  35  72  102  148  185
# 表向きになる相刘度数  0.35  0.36  ア  イ  ウ
# .  {{response}}
# .  {{response}}
# .  {{response}}
# .  {{response}}
# .  {{response}}
# .  {{response}}
# .  {{response}}
# .  {{response}}
# .  {{response}}
# .  {{response}}
# .  {{response}}
# .  {{response}}
# .  {{response}}
# .  {{response}}
# .  {{response}}
# .  {{response}}
# .  {{response}}
# .  {{response}}
# .  {{response}}
# .  {{response}}
# .  {{response}}
# .  {{response}}
# .  {{response}}
# .  {{response}}
# .  {{response}}
# .  {{response}}
# .  {{response}}
# .  {{response}}
# .  {{response}}
# .  {{response}}
# .  {{response}}
# .  {{response}}
# .  {{response}}
# .  {{response}}
# .  {{response}}
# .  {{response}}
# .  {{response}}
# .  {{response}}
# .  {{response}}
# .  {{response}}
# .  {{response}}
# .  {{response}}
# .  {{response}}
# .  {{response}}
# .  {{response}}
# .  {{response}}
# .  {{response}}
# .  {{response}}
# .  {{response}}
# .  {{response}}
# .  {{response}}
# .  {{response}}
# .  {{response}}
# .  {{response}}
# .  {{response}}
# .  {{response}}
# .  {{response}}
# .  {{response}}
# .  {{response}}
# .  {{response}}
# .  {{response}}
# .  {{response}}
# .  {{response}}
# .  {{response}}
# .  {{response}}
# .  {{response}}
# .  {{response}}
# .  {{response}}
# .  {{response}}
# (a)記録が15秒未満の生徒は,~~全体の何\%か。.  15秒未満の記録を持つ生徒の割合~=~{{response}}\%
# (b)記録が15.3秒であった生徒は,~~50人全体では速い方であるといえるか。あてはまるものを選びなさい。
# (a)記録が15秒未満の生徒は,~~全体の何\%か。.  15秒未満の記録を持つ生徒の割合~=~{{response}}\%
# (b)記録が14.9秒であった生徒は,~~40人全体では速い方であるといえるか。あてはまるものを選びなさい。
# (a)記録が15秒未満の生徒は,~~全体の何\%か。.  15秒未満の記録を持つ生徒の割合~=~{{response}}\%
# (b)記録が15.3秒であった生徒は,~~50人全体では速い方であるといえるか。あてはまるものを選びなさい。
# (a)記録が15秒未満の生徒は,~~全体の何\%か。.  15秒未満の記録を持つ生徒の割合~=~{{response}}\%
# (b)記録が14.7秒であった生徒は,~~50人全体では速い方であるといえるか。あてはまるものを選びなさい。
# (a)記録が15秒未満の生徒は,~~全体の何\%か。.  15秒未満の記録を持つ生徒の割合~=~{{response}}\%
# (b)記録が16.3秒であった生徒は,~~40人全体では速い方であるといえるか。あてはまるものを選びなさい。
# (a)記録が15秒未満の生徒は,~~全体の何\%か。.  15秒未満の記録を持つ生徒の割合~=~{{response}}\%
# (b)記録が15.9秒であった生徒は,~~50人全体では速い方であるといえるか。あてはまるものを選びなさい。
# (a)記録が15秒未満の生徒は,~~全体の何\%か。.  15秒未満の記録を持つ生徒の割合~=~{{response}}\%
# (b)記録が14.1秒であった生徒は,~~40人全体では速い方であるといえるか。あてはまるものを選びなさい。
# (a)記録が15秒未満の生徒は,~~全体の何\%か。.  15秒未満の記録を持つ生徒の割合~=~{{response}}\%
# (b)記録が14.4秒であった生徒は,~~40人全体では速い方であるといえるか。あてはまるものを選びなさい。
# (a)記録が15秒未満の生徒は,~~全体の何\%か。.  15秒未満の記録を持つ生徒の割合~=~{{response}}\%
# (b)記録が14.6秒であった生徒は,~~50人全体では速い方であるといえるか。あてはまるものを選びなさい。
# (a)記録が15秒未満の生徒は,~~全体の何\%か。.  15秒未満の記録を持つ生徒の割合~=~{{response}}\%
# (b)記録が16.4秒であった生徒は,~~50人全体では速い方であるといえるか。あてはまるものを選びなさい。
# 次の各組の数の大小を比べ,~~不等号を用いて表しなさい。+5,~~  -8,~~  0,~~  -1.01,~~  -0.01,~~  -4
# 次の各組の数の大小を比べ,~~不等号を用いて表しなさい。+2,~~  -4,~~  0,~~  -2,~~  -0.02,~~  -2.01
# 次の各組の数の大小を比べ,~~不等号を用いて表しなさい。+1,~~  -3,~~  0,~~  -1.01,~~  -0.01,~~  -2
# 次の各組の数の大小を比べ,~~不等号を用いて表しなさい。+3,~~  -5,~~  0,~~  -3.01,~~  -0.03,~~  -4
# 次の各組の数の大小を比べ,~~不等号を用いて表しなさい。+1,~~  -5,~~  0,~~  -1.01,~~  -0.01,~~  -2
# 次の各組の数の大小を比べ,~~不等号を用いて表しなさい。+8,~~  -8,~~  0,~~  -1.02,~~  -0.02,~~  -6
# 次の各組の数の大小を比べ,~~不等号を用いて表しなさい。+3,~~  -6,~~  0,~~  -1.01,~~  -0.01,~~  -4
# 次の各組の数の大小を比べ,~~不等号を用いて表しなさい。+7,~~  -9,~~  0,~~  -2.01,~~  -0.02,~~  -5
# 次の各組の数の大小を比べ,~~不等号を用いて表しなさい。+4,~~  -7,~~  0,~~  -2.01,~~  -0.01,~~  -3
# 次の各組の数の大小を比べ,~~不等号を用いて表しなさい。+1,~~  -6,~~  0,~~  -1.01,~~  -0.01,~~  -4
# 図のように2つの四角形ア,~~ウがある。アを移動してウに重ねるには,~~平行移動,~~対称移動,~~回転移動のうちの2つの移動を組み合わせることが必要である。その移動の方法を,~~図の中の文字を用いて説明したものを選びなさい。
# 図のように2つの四角形ア,~~ウがある。アを移動してウに重ねるには,~~平行移動,~~対称移動,~~回転移動のうちの2つの移動を組み合わせることが必要である。その移動の方法を,~~図の中の文字を用いて説明したものを選びなさい。
# 図のように2つの四角形ア,~~ウがある。アを移動してウに重ねるには,~~平行移動,~~対称移動,~~回転移動のうちの2つの移動を組み合わせることが必要である。その移動の方法を,~~図の中の文字を用いて説明したものを選びなさい。
# 図のように2つの四角形ア,~~ウがある。アを移動してウに重ねるには,~~平行移動,~~対称移動,~~回転移動のうちの2つの移動を組み合わせることが必要である。その移動の方法を,~~図の中の文字を用いて説明したものを選びなさい。
# 図のように2つの四角形ア,~~ウがある。アを移動してウに重ねるには,~~平行移動,~~対称移動,~~回転移動のうちの2つの移動を組み合わせることが必要である。その移動の方法を,~~図の中の文字を用いて説明したものを選びなさい。
# 図のように2つの四角形ア,~~ウがある。アを移動してウに重ねるには,~~平行移動,~~対称移動,~~回転移動のうちの2つの移動を組み合わせることが必要である。その移動の方法を,~~図の中の文字を用いて説明したものを選びなさい。
# 図のように2つの四角形ア,~~ウがある。アを移動してウに重ねるには,~~平行移動,~~対称移動,~~回転移動のうちの2つの移動を組み合わせることが必要である。その移動の方法を,~~図の中の文字を用いて説明したものを選びなさい。
# 図のように2つの四角形ア,  ~~イがある。アを移動してイに重ねるには,~~平行移動,~~対称移動,~~回転移動のどれを使えばよいか,~~答えたものを選びなさい。
# 図のように2つの四角形ア,  ~~イがある。アを移動してイに重ねるには,~~平行移動,~~対称移動,~~回転移動のどれを使えばよいか,~~答えたものを選びなさい。
# 図のように2つの四角形ア,  ~~イがある。アを移動してイに重ねるには,~~平行移動,~~対称移動,~~回転移動のどれを使えばよいか,~~答えたものを選びなさい。
# 図のように2つの四角形ア,  ~~イがある。アを移動してイに重ねるには,~~平行移動,~~対称移動,~~回転移動のどれを使えばよいか,~~答えたものを選びなさい。
# 図のように2つの四角形ア,  ~~イがある。アを移動してイに重ねるには,~~平行移動,~~対称移動,~~回転移動のどれを使えばよいか,~~答えたものを選びなさい。
# 図のように2つの四角形ア,  ~~イがある。アを移動してイに重ねるには,~~平行移動,~~対称移動,~~回転移動のどれを使えばよいか,~~答えたものを選びなさい。
# 図のように2つの四角形ア,  ~~イがある。アを移動してイに重ねるには,~~平行移動,~~対称移動,~~回転移動のどれを使えばよいか,~~答えたものを選びなさい。
# 図のように2つの四角形ア,  ~~イがある。アを移動してイに重ねるには,~~平行移動,~~対称移動,~~回転移動のどれを使えばよいか,~~答えたものを選びなさい。
# 図のように2つの四角形ア,  ~~イがある。アを移動してイに重ねるには,~~平行移動,~~対称移動,~~回転移動のどれを使えばよいか,~~答えたものを選びなさい。
# 図のように2つの四角形ア,  ~~イがある。アを移動してイに重ねるには,~~平行移動,~~対称移動,~~回転移動のどれを使えばよいか,~~答えたものを選びなさい。
# (a)+14.2.  +14.2の絶対値~=~{{response}}
# (b)-124.  -124の絶対値~=~{{response}}
# (c)-\dfrac{5}{6}.  -\dfrac{5}{6}の絶対値~=~{{response}}
# (a)+10.2.  +10.2の絶対値~=~{{response}}
# (c)-\dfrac{1}{7}.  -\dfrac{1}{7}の絶対値~=~{{response}}
# (a)+18.5.  +18.5の絶対値~=~{{response}}
# (b)-170.  -170の絶対値~=~{{response}}
# (c)-\dfrac{9}{2}.  -\dfrac{9}{2}の絶対値~=~{{response}}
# (a)+22.3.  +22.3の絶対値~=~{{response}}
# (b)-155.  -155の絶対値~=~{{response}}
# (c)-\dfrac{7}{9}.  -\dfrac{7}{9}の絶対値~=~{{response}}
# (a)+15.1.  +15.1の絶対値~=~{{response}}
# (b)-220.  -220の絶対値~=~{{response}}
# (c)-\dfrac{8}{5}.  -\dfrac{8}{5}の絶対値~=~{{response}}
# (a)+14.4.  +14.4の絶対値~=~{{response}}
# (b)-138.  -138の絶対値~=~{{response}}
# (c)-\dfrac{5}{8}.  -\dfrac{5}{8}の絶対値~=~{{response}}
# (a)+16.8.  +16.8の絶対値~=~{{response}}
# (b)-190.  -190の絶対値~=~{{response}}
# (c)-\dfrac{2}{3}.  -\dfrac{2}{3}の絶対値~=~{{response}}
# (a)+17.9.  +17.9の絶対値~=~{{response}}
# (b)-140.  -140の絶対値~=~{{response}}
# (c)-\dfrac{1}{8}.  -\dfrac{1}{8}の絶対値~=~{{response}}
# (a)+13.9.  +13.9の絶対値~=~{{response}}
# (b)-200.  -200の絶対値~=~{{response}}
# (c)-\dfrac{5}{8}.  -\dfrac{5}{8}の絶対値~=~{{response}}
# (a)+12.6.  +12.6の絶対値~=~{{response}}
# (b)-100.  -100の絶対値~=~{{response}}
# (c)-\dfrac{3}{7}.  -\dfrac{3}{7}の絶対値~=~{{response}}
# (a)身長が160cm未満の生徒は何人いるか。.  {{response}}人
# (b)身長が低い方から100番目の生徒はどの階級に属するか。あてはまる階級を選びなさい。
# (a)身長が160cm未満の生徒は何人いるか。.  {{response}}人
# (b)身長が低い方から100番目の生徒はどの階級に属するか。あてはまる階級を選びなさい。
# (a)身長が140cm未満の生徒は何人いるか。.  {{response}}人
# (b)身長が低い方から100番目の生徒はどの階級に属するか。あてはまる階級を選びなさい。
# (a)身長が170cm未満の生徒は何人いるか。.  {{response}}人
# (b)身長が低い方から100番目の生徒はどの階級に属するか。あてはまる階級を選びなさい。
# (a)身長が150cm未満の生徒は何人いるか。.  {{response}}人
# (b)身長が低い方から100番目の生徒はどの階級に属するか。あてはまる階級を選びなさい。
# (a)累積度数の欄をうめて,~~表を完成させなさい。.  ~~階級  (cm)  ~~度数(人)  ~~累積度数(人)
# 以上~~~未満
# 45~~~50  ~~~~~~~8  {{response}}
# 50~~~55  ~~~~~~~10  {{response}}
# 55~~~60  ~~~~~~~13  {{response}}
# 60~~~65  ~~~~~~~16  {{response}}
# 65~~~70  ~~~~~~~11  {{response}}
# 70~~~75  ~~~~~~~9  {{response}}
# ~~  計  ~~  67  ~~  \raisebox{5pt}{$\underline{~~~~}$}
# (b)記録が60cm未満の生徒は何人いるか求めなさい。.  {{response}}人
# (a)累積度数の欄をうめて,~~表を完成させなさい。.  ~~階級  (cm)  ~~度数(人)  ~~累積度数(人)
# 以上~~~未満
# 30~~~35  ~~~~~~~2  {{response}}
# 35~~~40  ~~~~~~~6  {{response}}
# 40~~~45  ~~~~~~~10  {{response}}
# 45~~~50  ~~~~~~~12  {{response}}
# 50~~~55  ~~~~~~~8  {{response}}
# 55~~~60  ~~~~~~~2  {{response}}
# ~~  計  ~~  40  ~~  \raisebox{5pt}{$\underline{~~~~}$}
# (b)記録が45cm未満の生徒は何人いるか求めなさい。.  {{response}}人
# (a)累積度数の欄をうめて,~~表を完成させなさい。.  ~~階級  (cm)  ~~度数(人)  ~~累積度数(人)
# 以上~~~未満
# 40~~~45  ~~~~~~~4  {{response}}
# 45~~~50  ~~~~~~~8  {{response}}
# 50~~~55  ~~~~~~~15  {{response}}
# 55~~~60  ~~~~~~~15  {{response}}
# 60~~~65  ~~~~~~~10  {{response}}
# 65~~~70  ~~~~~~~8  {{response}}
# ~~  計  ~~  60  ~~  \raisebox{5pt}{$\underline{~~~~}$}
# (b)記録が55cm未満の生徒は何人いるか求めなさい。.  {{response}}人
# (a)累積度数の欄をうめて,~~表を完成させなさい。.  ~~階級  (cm)  ~~度数(人)  ~~累積度数(人)
# 以上~~~未満
# 25~~~30  ~~~~~~~2  {{response}}
# 30~~~35  ~~~~~~~8  {{response}}
# 35~~~40  ~~~~~~~12  {{response}}
# 40~~~45  ~~~~~~~15  {{response}}
# 45~~~50  ~~~~~~~9  {{response}}
# 50~~~55  ~~~~~~~4  {{response}}
# ~~  計  ~~  50  ~~  \raisebox{5pt}{$\underline{~~~~}$}
# (b)記録が40cm未満の生徒は何人いるか求めなさい。.  {{response}}人
# (a)累積度数の欄をうめて,~~表を完成させなさい。.  ~~階級  (cm)  ~~度数(人)  ~~累積度数(人)
# 以上~~~未満
# 35~~~40  ~~~~~~~3  {{response}}
# 40~~~45  ~~~~~~~7  {{response}}
# 45~~~50  ~~~~~~~12  {{response}}
# 50~~~55  ~~~~~~~15  {{response}}
# 55~~~60  ~~~~~~~9  {{response}}
# 60~~~65  ~~~~~~~4  {{response}}
# ~~  計  ~~  50  ~~  \raisebox{5pt}{$\underline{~~~~}$}
# (b)記録が50cm未満の生徒は何人いるか求めなさい。.  {{response}}人
# (a)表のア~ウにあてはまる数を求めなさい。ただし,~~小数第3位を四捨五入して答えなさい。.  ア~=~{{response}}イ~=~{{response}}ウ~=~{{response}}
# (b)キャップを投げる回数を多くすると,~~表向きになる相対度数はどんな値に近づくと考えられるか。小数第2位までの数で答えなさい。.  {{response}}
# (c)このキャップを投げたとき,~~表向きになる確率はどの程度と考えられるか。小数第2位までの数で答えなさい。.  {{response}}
# (a)表のア~ウにあてはまる数を求めなさい。ただし,~~小数第3位を四捨五入して答えなさい。.  ア~=~{{response}}イ~=~{{response}}ウ~=~{{response}}
# (b)キャップを投げる回数を多くすると,~~表向きになる相対度数はどんな値に近づくと考えられるか。小数第2位までの数で答えなさい。.  {{response}}
# (c)このキャップを投げたとき,~~表向きになる確率はどの程度と考えられるか。小数第2位までの数で答えなさい。.  {{response}}
# (a)表のア~ウにあてはまる数を求めなさい。ただし,~~小数第3位を四捨五入して答えなさい。.  ア~=~{{response}}イ~=~{{response}}ウ~=~{{response}}
# (b)キャップを投げる回数を多くすると,~~表向きになる相対度数はどんな値に近づくと考えられるか。小数第2位までの数で答えなさい。.  {{response}}
# (c)このキャップを投げたとき,~~表向きになる確率はどの程度と考えられるか。小数第2位までの数で答えなさい。.  {{response}}
# (a)表のア~ウにあてはまる数を求めなさい。ただし,~~小数第3位を四捨五入して答えなさい。.  ア~=~{{response}}イ~=~{{response}}ウ~=~{{response}}
# (b)キャップを投げる回数を多くすると,~~表向きになる相対度数はどんな値に近づくと考えられるか。小数第2位までの数で答えなさい。.  {{response}}
# (c)このキャップを投げたとき,~~表向きになる確率はどの程度と考えられるか。小数第2位までの数で答えなさい。.  {{response}}
# (a)表のア~ウにあてはまる数を求めなさい。ただし,~~小数第3位を四捨五入して答えなさい。.  ア~=~{{response}}イ~=~{{response}}ウ~=~{{response}}
# (b)キャップを投げる回数を多くすると,~~表向きになる相対度数はどんな値に近づくと考えられるか。小数第2位までの数で答えなさい。.  {{response}}
# (c)このキャップを投げたとき,~~表向きになる確率はどの程度と考えられるか。小数第2位までの数で答えなさい。.  {{response}}
# 次の各組の数の大小を,~~不等号を用いて表しなさい。-\dfrac{3}{5},~~  -\dfrac{1}{3},~~  -\dfrac{8}{9},~~  -\dfrac{2}{5}
# 次の各組の数の大小を,~~不等号を用いて表しなさい。-\dfrac{3}{5},~~  -\dfrac{1}{4},~~  -\dfrac{3}{4},~~  -\dfrac{2}{5}
# 次の各組の数の大小を,~~不等号を用いて表しなさい。-\dfrac{3}{5},~~  -\dfrac{1}{7},~~  -\dfrac{4}{5},~~  -\dfrac{3}{7}
# 次の各組の数の大小を,~~不等号を用いて表しなさい。-\dfrac{5}{9},~~  -\dfrac{1}{4},~~  -\dfrac{5}{6},~~  -\dfrac{1}{3}
# 次の各組の数の大小を,~~不等号を用いて表しなさい。-\dfrac{1}{2},~~  -\dfrac{1}{8},~~  -\dfrac{3}{4},~~  -\dfrac{2}{5}
# 次の各組の数の大小を,~~不等号を用いて表しなさい。-\dfrac{1}{2},~~  -\dfrac{1}{4},~~  -\dfrac{3}{4},~~  -\dfrac{2}{5}
# 次の各組の数の大小を,~~不等号を用いて表しなさい。-\dfrac{2}{5},~~  -\dfrac{1}{6},~~  -\dfrac{7}{9},~~  -\dfrac{1}{4}
# 次の各組の数の大小を,~~不等号を用いて表しなさい。-\dfrac{1}{2},~~  -\dfrac{1}{3},~~  -\dfrac{4}{5},~~  -\dfrac{2}{5}
# 次の各組の数の大小を,~~不等号を用いて表しなさい。-\dfrac{1}{2},~~  -\dfrac{1}{3},~~  -\dfrac{3}{4},~~  -\dfrac{2}{5}
# 次の各組の数の大小を,~~不等号を用いて表しなさい。-\dfrac{2}{3},~~  -\dfrac{1}{3},~~  -\dfrac{4}{5},~~  -\dfrac{2}{5}
# 次の各組の数の大小を,~~不等号を用いて表しなさい。+0.06,~~-  0.06,~~  +0.6,~  -0.6
# 次の各組の数の大小を,~~不等号を用いて表しなさい。+0.04,~~-  0.04,~~  +0.4,~  -0.4
# 次の各組の数の大小を,~~不等号を用いて表しなさい。+0.07,~~-  0.07,~~  +0.7,~  -0.7
# 次の各組の数の大小を,~~不等号を用いて表しなさい。+0.012,~~-  0.012,~~  +0.12,~  -0.12
# 次の各組の数の大小を,~~不等号を用いて表しなさい。+0.01,~~-  0.01,~~  +0.1,~  -0.1
# 次の各組の数の大小を,~~不等号を用いて表しなさい。+0.02,~~-  0.02,~~  +0.2,~  -0.2
# 次の各組の数の大小を,~~不等号を用いて表しなさい。+0.09,~~-  0.09,~~  +0.9,~  -0.9
# 次の各組の数の大小を,~~不等号を用いて表しなさい。+0.08,~~-  0.08,~~  +0.8,~  -0.8
# 次の各組の数の大小を,~~不等号を用いて表しなさい。+0.05,~~-  0.05,~~  +0.5,~  -0.5
# 次の各組の数の大小を,~~不等号を用いて表しなさい。+0.03,~~-  0.03,~~  +0.3,~  -0.3
# ~~~~(+7)-(+1)=(+7)+(-1)=+(7-1)=+6
# ~~~~(-9)-(+1)=(-9)+(-1)=-(9+1)=-10
# ~~~(+9)-(-1)=(+9)+(+1)=+(9+1)=+10
# ~~~~(-4)-(-3)=(-4)+(+3)=-(4-3)=-1
# ~~~~(+7)-(+9)=(+7)+(-9)=+(7-9)=-2
# ~~~~(+8)-(+8)=(+8)+(-8)=+(8-8)=0
# ~~~~(-1)-(-7)=(-1)+(+7)=-(1-7)=+6
# ~~~~0-(+3)=0+(-3)=0-3=-3
# ~~~~0-(-1)=0+(+1)=0+1=+1
# ~~~~(+0.4)-(+0.1)=(+0.4)+(-0.1)=+(0.4-0.1)=+0.3
# ~~~~(-1.9)-(-2.8)=(-1.9)+(+2.8)=-(1.9-2.8)=+0.9
# ~~~~(+2.4)-(-1.1)=(+2.4)+(+1.1)=+(2.4+1.1)=+3.5
# ~~~~(+0.1)-(+0.46)=(+0.1)+(-0.46)=+(0.1-0.46)=-0.36
# ~~~~(-0.45)-(+0.1)=(-0.45)+(-0.1)=-(0.45+0.1)=-0.55
# ~~~~(-1.78)-(-4.8)=(-1.78)+(+4.8)=-(1.78-4.8)=+3.02
# ~~~~\left(+\dfrac{4}{9}\right)-\left(-\dfrac{7}{9}\right)=\left(+\dfrac{4}{9}\right)+\left(+\dfrac{7}{9}\right)=+\left(\dfrac{4}{9}+\dfrac{7}{9}\right)=+\left(\dfrac{4+7}{9}\right)=+\dfrac{11}{9}
# ~~~~\left(-\dfrac{18}{7}\right)-\left(+\dfrac{20}{7}\right)=\left(-\dfrac{18}{7}\right)+\left(-\dfrac{20}{7}\right)=-\left(\dfrac{18}{7}+\dfrac{20}{7}\right)=-\left(\dfrac{18+20}{7}\right)=-\dfrac{38}{7}
# ~~~~\left(-\dfrac{3}{5}\right)-\left(+\dfrac{2}{7}\right)=\left(-\dfrac{3}{5}\right)+\left(-\dfrac{2}{7}\right)=-\left(\dfrac{3}{5}+\dfrac{2}{7}\right)=-\left(\dfrac{3\times  7}{5\times  7}+\dfrac{2\times  5}{7\times  5}\right)=-\left(\dfrac{21}{35}+\dfrac{10}{35}\right)=-\left(\dfrac{21+10}{35}\right)=-\dfrac{31}{35}
# ~~~~\left(+\dfrac{3}{2}\right)-\left(-\dfrac{2}{3}\right)=\left(+\dfrac{3}{2}\right)+\left(+\dfrac{2}{3}\right)=+\left(\dfrac{3}{2}+\dfrac{2}{3}\right)=+\left(\dfrac{3\times  3}{2\times  3}+\dfrac{2\times  2}{3\times  2}\right)=+\left(\dfrac{9}{6}+\dfrac{4}{6}\right)=+\left(\dfrac{9+4}{6}\right)=+\dfrac{13}{6}
# ~~~~\left(-\dfrac{13}{15}\right)-\left(-\dfrac{1}{6}\right)=\left(-\dfrac{13}{15}\right)+\left(+\dfrac{1}{6}\right)=-\left(\dfrac{13}{15}-\dfrac{1}{6}\right)=-\left(\dfrac{13\times  2}{15\times  2}-\dfrac{1\times  5  }{6\times  5  }\right)=-\left(\dfrac{26}{30}-\dfrac{5}{30}\right)=-\left(\dfrac{26-5}{30}\right)=-\dfrac{21}{30}=-\dfrac{7}{10}
# ~~~~(+2)-(-2)=(+2)+(+2)=+(2+2)=+4
# ~~~~(-1)-(+1)=(-1)+(-1)=-(1+1)=-2
# ~~~~(-6)-(-6)=(-6)+(+6)=-(6-6)=0
# ~~~~(-8)-0=-(8+0)=-8
# ~~~~(+3)-(-35)=(+3)+(+35)=+(3+35)=+38
# ~~~~(+2)-(+22)=(+2)+(-22)=+(2-22)=-20
# ~~~~(+26)-(-14)=(+26)+(+14)=+(26+14)=+40
# ~~~~(-11)-(-18)=(-11)+(+18)=-(11-18)=+7
# ~~~~(-32)-(+35)=(-32)+(-35)=-(32+35)=-67
# ~~~~(+17)-(+42)=(+17)+(-42)=+(17-42)=-25
# ~~~~(+18)-(-31)=(+18)+(+31)=+(18+31)=+49
# ~~~~(-51)-(-13)=(-51)+(+13)=-(51-13)=-38
# ~~~~(-5.2)-(-4.5)=(-5.2)+(+4.5)=-(5.2-4.5)=-0.7
# ~~~~\left(-\dfrac{20}{9}\right)-\left(-\dfrac{5}{9}\right)=\left(-\dfrac{20}{9}\right)+\left(+\dfrac{5}{9}\right)=-\left(\dfrac{20}{9}-\dfrac{5}{9}\right)=-\left(\dfrac{20-5}{9}\right)=-\dfrac{15}{9}=-\dfrac{5}{3}
# ~~~~(-1.1)-(-0.47)=(-1.1)+(+0.47)=-(1.1-0.47)=-0.63
# ~~~~(-0.29)-(-2.6)=(-0.29)+(+2.6)=-(0.29-2.6)=+  2.31
#
#
#
#
#
#
# 0  +  (+  2)=  0  +  2=  2
# 0  +  (-~2)=  0  -  2=  -  2
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# (-~5)  +~0=~-~5  +~0=~-~5
# 0  +  (-~5)=~0~-~5=~-~5
#
#
#
#
#
#
#
# (a)15秒未満の記録を持つ生徒の割合~=~48\%
# (b)速い方であるといえる。
# (a)15秒未満の記録を持つ生徒の割合~=~72.5\%
# (b)速い方であるといえる。
# (a)15秒未満の記録を持つ生徒の割合~=~40\%
# (b)速い方であるといえる。
# (a)15秒未満の記録を持つ生徒の割合~=~82\%
# (b)速い方であるといえる。
# (a)15秒未満の記録を持つ生徒の割合~=~62.5\%
# (b)速い方であるといえる。
# (a)15秒未満の記録を持つ生徒の割合~=~40\%
# (b)速い方であるといえる。
# (a)15秒未満の記録を持つ生徒の割合~=~80\%
# (b)速い方であるといえる。
# (a)15秒未満の記録を持つ生徒の割合~=~60\%
# (b)速い方であるといえる。
# (a)15秒未満の記録を持つ生徒の割合~=~56\%
# (b)速い方であるといえる。
# (a)15秒未満の記録を持つ生徒の割合~=~44\%
# (b)速い方であるといえる。
# 正の数は0より大きく,~~絶対値が大きいほど大きい。負の数は0より小さく,~~絶対値が小さいほど大きい。-8<  -4<  -1.01<  -0.01<  0<  +5
# 正の数は0より大きく,~~絶対値が大きいほど大きい。負の数は0より小さく,~~絶対値が小さいほど大きい。-4<  -2.01<  -2<  -0.02<  0<  +2
# 正の数は0より大きく,~~絶対値が大きいほど大きい。負の数は0より小さく,~~絶対値が小さいほど大きい。-3<  -2<  -1.01<  -0.01<  0<  +1
# 正の数は0より大きく,~~絶対値が大きいほど大きい。負の数は0より小さく,~~絶対値が小さいほど大きい。-5<  -4<  -3.01<  -0.03<  0<  +3
# 正の数は0より大きく,~~絶対値が大きいほど大きい。負の数は0より小さく,~~絶対値が小さいほど大きい。-5<  -2<  -1.01<  -0.01<  0<  +1
# 正の数は0より大きく,~~絶対値が大きいほど大きい。負の数は0より小さく,~~絶対値が小さいほど大きい。-8<  -6<  -1.02<  -0.02<  0<  +8
# 正の数は0より大きく,~~絶対値が大きいほど大きい。負の数は0より小さく,~~絶対値が小さいほど大きい。-6<  -4<  -1.01<  -0.01<  0<  +3
# 正の数は0より大きく,~~絶対値が大きいほど大きい。負の数は0より小さく,~~絶対値が小さいほど大きい。-9<  -5<  -2.01<  -0.02<  0<  +7
# 正の数は0より大きく,~~絶対値が大きいほど大きい。負の数は0より小さく,~~絶対値が小さいほど大きい。-7<  -3<  -2.01<  -0.01<  0<  +4
# 正の数は0より大きく,~~絶対値が大きいほど大きい。負の数は0より小さく,~~絶対値が小さいほど大きい。-6<  -4<  -1.01<  -0.01<  0<  +1
# 直線\ellを対称軸とする対称移動をし,~~さらに点Gを中心として時計回りに90\degreeの回転移動をおこなう。
# 直線\ellを対称軸とする対称移動をし,~~さらに点Gを中心として時計回りに90\degreeの回転移動をおこなう。
# 直線\ellを対称軸とする対称移動をし,~~さらに点Gを中心として時計回りに180\degreeの回転移動をおこなう。
# 直線\ellを対称軸とする対称移動をし,~~さらに点Gを中心として時計回りに180\degreeの回転移動をおこなう。
# 直線\ellを対称軸とする対称移動をし,~~さらに点Gを中心として時計回りに90\degreeの回転移動をおこなう。
# 直線\ellを対称軸とする対称移動をし,~~さらに点Gを中心として時計回りに90\degreeの回転移動をおこなう。
# 直線\ellを対称軸とする対称移動をし,~~さらに点Gを中心として時計回りに90\degreeの回転移動をおこなう。
# 平行移動
# 平行移動
# 平行移動
# 平行移動
# 平行移動
# 平行移動
# 平行移動
# 平行移動
# 平行移動
# 平行移動
# (a)絶対値\cdots数から符号を取り去った数。数直線上で,~~その数に対応する点と0との距離になる。+14.2の絶対値  =  14.2
# (b)絶対値\cdots数から符号を取り去った数。数直線上で,~~その数に対応する点と0との距離になる。-124の絶対値  =  124
# (c)絶対値\cdots数から符号を取り去った数。数直線上で,~~その数に対応する点と0との距離になる。-\dfrac{5}{6}の絶対値  =  \dfrac{5}{6}
# (a)絶対値\cdots数から符号を取り去った数。数直線上で,~~その数に対応する点と0との距離になる。+10.2の絶対値  =  10.2
# (c)絶対値\cdots数から符号を取り去った数。数直線上で,~~その数に対応する点と0との距離になる。-\dfrac{1}{7}の絶対値  =  \dfrac{1}{7}
# (a)絶対値\cdots数から符号を取り去った数。数直線上で,~~その数に対応する点と0との距離になる。+18.5の絶対値  =  18.5
# (b)絶対値\cdots数から符号を取り去った数。数直線上で,~~その数に対応する点と0との距離になる。-170の絶対値  =  170
# (c)絶対値\cdots数から符号を取り去った数。数直線上で,~~その数に対応する点と0との距離になる。-\dfrac{9}{2}の絶対値  =  \dfrac{9}{2}
# (a)絶対値\cdots数から符号を取り去った数。数直線上で,~~その数に対応する点と0との距離になる。+22.3の絶対値  =  22.3
# (b)絶対値\cdots数から符号を取り去った数。数直線上で,~~その数に対応する点と0との距離になる。-155の絶対値  =  155
# (c)絶対値\cdots数から符号を取り去った数。数直線上で,~~その数に対応する点と0との距離になる。-\dfrac{7}{9}の絶対値  =  \dfrac{7}{9}
# (a)絶対値\cdots数から符号を取り去った数。数直線上で,~~その数に対応する点と0との距離になる。+15.1の絶対値  =  15.1
# (b)絶対値\cdots数から符号を取り去った数。数直線上で,~~その数に対応する点と0との距離になる。-220の絶対値  =  220
# (c)絶対値\cdots数から符号を取り去った数。数直線上で,~~その数に対応する点と0との距離になる。-\dfrac{8}{5}の絶対値  =  \dfrac{8}{5}
# (a)絶対値\cdots数から符号を取り去った数。数直線上で,~~その数に対応する点と0との距離になる。+14.4の絶対値  =  14.4
# (b)絶対値\cdots数から符号を取り去った数。数直線上で,~~その数に対応する点と0との距離になる。-138の絶対値  =  138
# (c)絶対値\cdots数から符号を取り去った数。数直線上で,~~その数に対応する点と0との距離になる。-\dfrac{5}{8}の絶対値  =  \dfrac{5}{8}
# (a)絶対値\cdots数から符号を取り去った数。数直線上で,~~その数に対応する点と0との距離になる。+16.8の絶対値  =  16.8
# (b)絶対値\cdots数から符号を取り去った数。数直線上で,~~その数に対応する点と0との距離になる。-190の絶対値  =  190
# (c)絶対値\cdots数から符号を取り去った数。数直線上で,~~その数に対応する点と0との距離になる。-\dfrac{2}{3}の絶対値  =  \dfrac{2}{3}
# (a)絶対値\cdots数から符号を取り去った数。数直線上で,~~その数に対応する点と0との距離になる。+17.9の絶対値  =  17.9
# (b)絶対値\cdots数から符号を取り去った数。数直線上で,~~その数に対応する点と0との距離になる。-140の絶対値  =  140
# (c)絶対値\cdots数から符号を取り去った数。数直線上で,~~その数に対応する点と0との距離になる。-\dfrac{1}{8}の絶対値  =  \dfrac{1}{8}
# (a)絶対値\cdots数から符号を取り去った数。数直線上で,~~その数に対応する点と0との距離になる。+13.9の絶対値  =  13.9
# (b)絶対値\cdots数から符号を取り去った数。数直線上で,~~その数に対応する点と0との距離になる。-200の絶対値  =  200
# (c)絶対値\cdots数から符号を取り去った数。数直線上で,~~その数に対応する点と0との距離になる。-\dfrac{5}{8}の絶対値  =  \dfrac{5}{8}
# (a)絶対値\cdots数から符号を取り去った数。数直線上で,~~その数に対応する点と0との距離になる。+12.6の絶対値  =  12.6
# (b)絶対値\cdots数から符号を取り去った数。数直線上で,~~その数に対応する点と0との距離になる。-100の絶対値  =  100
# (c)絶対値\cdots数から符号を取り去った数。数直線上で,~~その数に対応する点と0との距離になる。-\dfrac{3}{7}の絶対値  =  \dfrac{3}{7}
# (a)身長160cm未満の生徒は126人
# (b)155cm以上160cm未満の階級
# (a)身長160cm未満の生徒は121人
# (b)155cm以上160cm未満の階級
# (a)身長140cm未満の生徒は113人
# (b)135cm以上140cm未満の階級
# (a)身長170cm未満の生徒は116人
# (b)165cm以上170cm未満の階級
# (a)身長150cm未満の生徒は131人
# (b)145cm以上150cm未満の階級
# (a)~~階級  (cm)  ~~度数(人)  ~~累積度数(人)
# 以上~~~未満
# 45~~~50  ~~~~~~~8  ~~~~~~~~~8~
# 50~~~55  ~~~~~~~10  ~~~~~~~~~18~
# 55~~~60  ~~~~~~~13  ~~~~~~~~~31~
# 60~~~65  ~~~~~~~16  ~~~~~~~~~47~
# 65~~~70  ~~~~~~~11  ~~~~~~~~~58~
# 70~~~75  ~~~~~~~9  ~~~~~~~~~67~
# ~~  計  ~~  67  ~~  \raisebox{5pt}{$\underline{~~~~}$}
# (b)表から,~~31人の生徒が60cm未満の記録を持っていることがわかります。
# (a)~~階級  (cm)  ~~度数(人)  ~~累積度数(人)
# 以上~~~未満
# 30~~~35  ~~~~~~~2  ~~~~~~~~~2~
# 35~~~40  ~~~~~~~6  ~~~~~~~~~8~
# 40~~~45  ~~~~~~~10  ~~~~~~~~~18~
# 45~~~50  ~~~~~~~12  ~~~~~~~~~30~
# 50~~~55  ~~~~~~~8  ~~~~~~~~~38~
# 55~~~60  ~~~~~~~2  ~~~~~~~~~40~
# ~~  計  ~~  40  ~~  \raisebox{5pt}{$\underline{~~~~}$}
# (b)表から,~~18人の生徒が45cm未満の記録を持っていることがわかります。
# (a)~~階級  (cm)  ~~度数(人)  ~~累積度数(人)
# 以上~~~未満
# 40~~~45  ~~~~~~~4  ~~~~~~~~~4~
# 45~~~50  ~~~~~~~8  ~~~~~~~~~12~
# 50~~~55  ~~~~~~~15  ~~~~~~~~~27~
# 55~~~60  ~~~~~~~15  ~~~~~~~~~42~
# 60~~~65  ~~~~~~~10  ~~~~~~~~~52~
# 65~~~70  ~~~~~~~8  ~~~~~~~~~60~
# ~~  計  ~~  60  ~~  \raisebox{5pt}{$\underline{~~~~}$}
# (b)表から,~~27人の生徒が55cm未満の記録を持っていることがわかります。
# (a)~~階級  (cm)  ~~度数(人)  ~~累積度数(人)
# 以上~~~未満
# 25~~~30  ~~~~~~~2  ~~~~~~~~~2~
# 30~~~35  ~~~~~~~8  ~~~~~~~~~10~
# 35~~~40  ~~~~~~~12  ~~~~~~~~~22~
# 40~~~45  ~~~~~~~15  ~~~~~~~~~37~
# 45~~~50  ~~~~~~~9  ~~~~~~~~~46~
# 50~~~55  ~~~~~~~4  ~~~~~~~~~50~
# ~~  計  ~~  50  ~~  \raisebox{5pt}{$\underline{~~~~}$}
# (b)表から,~~22人の生徒が40cm未満の記録を持っていることがわかります。
# (a)~~階級  (cm)  ~~度数(人)  ~~累積度数(人)
# 以上~~~未満
# 35~~~40  ~~~~~~~3  ~~~~~~~~~3~
# 40~~~45  ~~~~~~~7  ~~~~~~~~~10~
# 45~~~50  ~~~~~~~12  ~~~~~~~~~22~
# 50~~~55  ~~~~~~~15  ~~~~~~~~~37~
# 55~~~60  ~~~~~~~9  ~~~~~~~~~46~
# 60~~~65  ~~~~~~~4  ~~~~~~~~~50~
# ~~  計  ~~  50  ~~  \raisebox{5pt}{$\underline{~~~~}$}
# (b)表から,~~22人の生徒が50cm未満の記録を持っていることがわかります。
# (a)表向きになる相対度数  =\dfrac{表向きになった回数(回)}{投げた回数(回)}ア=0.18  イ=0.19  ウ=0.19
# (b)500回の相対度数から,~~求める答えは0.19です。
# (c)\lparenb\rparenで求めた相対度数より,~~求める確率は0.19になります。
# (a)表向きになる相対度数  =\dfrac{表向きになった回数(回)}{投げた回数(回)}ア=0.27  イ=0.28  ウ=0.28
# (b)500回の相対度数から,~~求める答えは0.28です。
# (c)\lparenb\rparenで求めた相対度数より,~~求める確率は0.28になります。
# (a)表向きになる相対度数  =\dfrac{表向きになった回数(回)}{投げた回数(回)}ア=0.43  イ=0.42  ウ=0.42
# (b)500回の相対度数から,~~求める答えは0.42です。
# (c)\lparenb\rparenで求めた相対度数より,~~求める確率は0.42になります。
# (a)表向きになる相対度数  =\dfrac{表向きになった回数(回)}{投げた回数(回)}ア=0.53  イ=0.52  ウ=0.52
# (b)500回の相対度数から,~~求める答えは0.52です。
# (c)\lparenb\rparenで求めた相対度数より,~~求める確率は0.52になります。
# (a)表向きになる相対度数  =\dfrac{表向きになった回数(回)}{投げた回数(回)}ア=0.34  イ=0.37  ウ=0.37
# (b)500回の相対度数から,~~求める答えは0.37です。
# (c)\lparenb\rparenで求めた相対度数より,~~求める確率は0.37になります。
# 正の数は0より大きく,~~絶対値が大きいほど大きい。負の数は0より小さく,~~絶対値が小さいほど大きい。-\dfrac{8}{9}<  -\dfrac{3}{5}<  -\dfrac{2}{5}<  -\dfrac{1}{3}
# 正の数は0より大きく,~~絶対値が大きいほど大きい。負の数は0より小さく,~~絶対値が小さいほど大きい。-\dfrac{3}{4}<  -\dfrac{3}{5}<  -\dfrac{2}{5}<  -\dfrac{1}{4}
# 正の数は0より大きく,~~絶対値が大きいほど大きい。負の数は0より小さく,~~絶対値が小さいほど大きい。-\dfrac{4}{5}<  -\dfrac{3}{5}<  -\dfrac{3}{7}<  -\dfrac{1}{7}
# 正の数は0より大きく,~~絶対値が大きいほど大きい。負の数は0より小さく,~~絶対値が小さいほど大きい。-\dfrac{5}{6}<  -\dfrac{5}{9}<  -\dfrac{1}{3}<  -\dfrac{1}{4}
# 正の数は0より大きく,~~絶対値が大きいほど大きい。負の数は0より小さく,~~絶対値が小さいほど大きい。-\dfrac{3}{4}<  -\dfrac{1}{2}<  -\dfrac{2}{5}<  -\dfrac{1}{8}
# 正の数は0より大きく,~~絶対値が大きいほど大きい。負の数は0より小さく,~~絶対値が小さいほど大きい。-\dfrac{3}{4}<  -\dfrac{1}{2}<  -\dfrac{2}{5}<  -\dfrac{1}{4}
# 正の数は0より大きく,~~絶対値が大きいほど大きい。負の数は0より小さく,~~絶対値が小さいほど大きい。-\dfrac{7}{9}<  -\dfrac{2}{5}<  -\dfrac{1}{4}<  -\dfrac{1}{6}
# 正の数は0より大きく,~~絶対値が大きいほど大きい。負の数は0より小さく,~~絶対値が小さいほど大きい。-\dfrac{4}{5}<  -\dfrac{1}{2}<  -\dfrac{2}{5}<  -\dfrac{1}{3}
# 正の数は0より大きく,~~絶対値が大きいほど大きい。負の数は0より小さく,~~絶対値が小さいほど大きい。-\dfrac{3}{4}<  -\dfrac{1}{2}<  -\dfrac{2}{5}<  -\dfrac{1}{3}
# 正の数は0より大きく,~~絶対値が大きいほど大きい。負の数は0より小さく,~~絶対値が小さいほど大きい。-\dfrac{4}{5}<  -\dfrac{2}{3}<  -\dfrac{2}{5}<  -\dfrac{1}{3}
# 正の数は0より大きく,~~絶対値が大きいほど大きい。負の数は0より小さく,~~絶対値が小さいほど大きい。-0.6  <  -0.06  <  +0.06  <  +0.6
# 正の数は0より大きく,~~絶対値が大きいほど大きい。負の数は0より小さく,~~絶対値が小さいほど大きい。-0.4  <  -0.04  <  +0.04  <  +0.4
# 正の数は0より大きく,~~絶対値が大きいほど大きい。負の数は0より小さく,~~絶対値が小さいほど大きい。-0.7  <  -0.07  <  +0.07  <  +0.7
# 正の数は0より大きく,~~絶対値が大きいほど大きい。負の数は0より小さく,~~絶対値が小さいほど大きい。-0.12  <  -0.012  <  +0.012  <  +0.12
# 正の数は0より大きく,~~絶対値が大きいほど大きい。負の数は0より小さく,~~絶対値が小さいほど大きい。-0.1  <  -0.01  <  +0.01  <  +0.1
# 正の数は0より大きく,~~絶対値が大きいほど大きい。負の数は0より小さく,~~絶対値が小さいほど大きい。-0.2  <  -0.02  <  +0.02  <  +0.2
# 正の数は0より大きく,~~絶対値が大きいほど大きい。負の数は0より小さく,~~絶対値が小さいほど大きい。-0.9  <  -0.09  <  +0.09  <  +0.9
# 正の数は0より大きく,~~絶対値が大きいほど大きい。負の数は0より小さく,~~絶対値が小さいほど大きい。-0.8  <  -0.08  <  +0.08  <  +0.8
# 正の数は0より大きく,~~絶対値が大きいほど大きい。負の数は0より小さく,~~絶対値が小さいほど大きい。-0.5  <  -0.05  <  +0.05  <  +0.5
# 正の数は0より大きく,~~絶対値が大きいほど大きい。負の数は0より小さく,~~絶対値が小さいほど大きい。-0.3  <  -0.03  <  +0.03  <  +0.3
# 6
# -10
# 10
# -1
# -2
# 0
# 6
# -3
# 1
# 0.3
# 0.9
# 3.5
# -0.36
# -0.55
# 3.02
# +\frac{11}{9}
# -\frac{38}{7}
# -\frac{31}{35}
# +\frac{13}{6}
# -\frac{21}{30}
# 4
# -2
# 0
# -8
# 38
# -20
# 40
# 7
# -67
# -25
# 49
# -38
# -0.7
# -\frac{15}{9}
# -0.63
# 2.31
# 6
# -10
# 7
# -2
# 4
# -3
# 2
# -2
# -0.3
# -1.1
# 1.9
# 4.6
# -0.8
# -6.4
# -1
# -0.5
# -  \frac{5}{12}
# \frac{3}{2}
# -  \frac{5}{6}
# \frac{-12}{15}
# -  \frac{11}{12}
# 0
# 14
# -6
# -5
# -5
# 17
# -39
# 23
# 0.16
# 0.45
# 3
# \frac{13}{90}
# 48
# この表だけでは判断できない。
# 速い方であるといえる。
# 遅い方であるといえる。
# これらの中にはどれもあてはまらない。
# 72.5
# 速い方であるといえる。
# 遅い方であるといえる。
# この表だけでは判断できない。
# これらの中にはどれもあてはまらない。
# 40
# この表だけでは判断できない。
# 速い方であるといえる。
# 遅い方であるといえる。
# これらの中にはどれもあてはまらない。
# 82
# この表だけでは判断できない。
# 速い方であるといえる。
# 遅い方であるといえる。
# これらの中にはどれもあてはまらない。
# 62.5
# この表だけでは判断できない。
# 速い方であるといえる。
# 遅い方であるといえる。
# これらの中にはどれもあてはまらない。
# 40
# 遅い方であるといえる。
# この表だけでは判断できない。
# 速い方であるといえる。
# これらの中にはどれもあてはまらない。
# 80
# 速い方であるといえる。
# 遅い方であるといえる。
# この表だけでは判断できない。
# これらの中にはどれもあてはまらない。
# 60
# この表だけでは判断できない。
# 速い方であるといえる。
# 遅い方であるといえる。
# これらの中にはどれもあてはまらない。
# 56
# 遅い方であるといえる。
# この表だけでは判断できない。
# 速い方であるといえる。
# これらの中にはどれもあてはまらない。
# 44
# 遅い方であるといえる。
# この表だけでは判断できない。
# 速い方であるといえる。
# これらの中にはどれもあてはまらない。
# -8<  -4<  -1.01<  -0.01<  0<  +5
# -4<  -8<  -1.01<  -0.01<  0<  +5
# -8<  -4<  -0.01<  -1.01<  0<  +5
# 0<  -4<  -1.01<  -0.01<  -8<  +5
# -2.01<  -4<  -2<  -0.02<  0<  +2
# -4<  -2.01<  -0.02<  -2<  0<  +2
# 0<  -2.01<  -2<  -0.02<  -4<  +2
# -4<  -2.01<  -2<  -0.02<  0<  +2
# -3<  -2<  -1.01<  -0.01<  0<  +1
# -2<  -3<  -1.01<  -0.01<  0<  +1
# -3<  -2<  -0.01<  -1.01<  0<  +1
# 0<  -2<  -1.01<  -0.01<  -3<  +1
# -4<  -5<  -3.01<  -0.03<  0<  +3
# -5<  -4<  -0.03<  -3.01<  0<  +3
# 0<  -4<  -3.01<  -0.03<  -5<  +3
# -5<  -4<  -3.01<  -0.03<  0<  +3
# 0<  -2<  -1.01<  -0.01<  -5<  +1
# -5<  -2<  -1.01<  -0.01<  0<  +1
# -2<  -5<  -1.01<  -0.01<  0<  +1
# -5<  -2<  -0.01<  -1.01<  0<  +1
# -8<  -6<  -1.02<  -0.02<  0<  +8
# -6<  -8<  -1.02<  -0.02<  0<  +8
# -8<  -6<  -0.02<  -1.02<  0<  +8
# 0<  -6<  -1.02<  -0.02<  -8<  +8
# -6<  -4<  -1.01<  -0.01<  0<  +3
# -4<  -6<  -1.01<  -0.01<  0<  +3
# -6<  -4<  -0.01<  -1.01<  0<  +3
# 0<  -4<  -1.01<  -0.01<  -6<  +3
# -9<  -5<  -2.01<  -0.02<  0<  +7
# -5<  -9<  -2.01<  -0.02<  0<  +7
# -9<  -5<  -0.02<  -2.01<  0<  +7
# 0<  -5<  -2.01<  -0.02<  -9<  +7
# -3<  -7<  -2.01<  -0.01<  0<  +4
# -7<  -3<  -0.01<  -2.01<  0<  +4
# 0<  -3<  -2.01<  -0.01<  -7<  +4
# -7<  -3<  -2.01<  -0.01<  0<  +4
# -4<  -6<  -1.01<  -0.01<  0<  +1
# -6<  -4<  -0.01<  -1.01<  0<  +1
# 0<  -4<  -1.01<  -0.01<  -6<  +1
# -6<  -4<  -1.01<  -0.01<  0<  +1
# 直線\ellを対称軸とする平行移動をし,~~さらに点Gを中心として時計回りに180\degreeの回転移動をおこなう。
# 直線\ellを対称軸とする対称移動をし,~~さらに点Gを中心として時計回りに90\degreeの回転移動をおこなう。
# 直線\ellを対称軸とする対称移動をし,~~さらに点Gを中心として時計回りに180\degreeの回転移動をおこなう。
# 直線\ellを対称軸とする平行移動をし,~~さらに点Gを中心として時計回りに90\degreeの回転移動をおこなう。
# 直線\ellを対称軸とする平行移動をし,~~さらに点Gを中心として時計回りに180\degreeの回転移動をおこなう。
# 直線\ellを対称軸とする対称移動をし,~~さらに点Gを中心として時計回りに90\degreeの回転移動をおこなう。
# 直線\ellを対称軸とする対称移動をし,~~さらに点Gを中心として時計回りに180\degreeの回転移動をおこなう。
# 直線\ellを対称軸とする平行移動をし,~~さらに点Gを中心として時計回りに90\degreeの回転移動をおこなう。
# 直線\ellを対称軸とする対称移動をし,~~さらに点Gを中心として時計回りに90\degreeの回転移動をおこなう。
# 直線\ellを対称軸とする平行移動をし,~~さらに点Gを中心として時計回りに180\degreeの回転移動をおこなう。
# 直線\ellを対称軸とする平行移動をし,~~さらに点Gを中心として時計回りに90\degreeの回転移動をおこなう。
# 直線\ellを対称軸とする対称移動をし,~~さらに点Gを中心として時計回りに180\degreeの回転移動をおこなう。
# 直線\ellを対称軸とする平行移動をし,~~さらに点Gを中心として時計回りに90\degreeの回転移動をおこなう。
# 直線\ellを対称軸とする対称移動をし,~~さらに点Gを中心として時計回りに180\degreeの回転移動をおこなう。
# 直線\ellを対称軸とする対称移動をし,~~さらに点Gを中心として時計回りに90\degreeの回転移動をおこなう。
# 直線\ellを対称軸とする平行移動をし,~~さらに点Gを中心として時計回りに180\degreeの回転移動をおこなう。
# 直線\ellを対称軸とする対称移動をし,~~さらに点Gを中心として時計回りに180\degreeの回転移動をおこなう。
# 直線\ellを対称軸とする平行移動をし,~~さらに点Gを中心として時計回りに90\degreeの回転移動をおこなう。
# 直線\ellを対称軸とする平行移動をし,~~さらに点Gを中心として時計回りに180\degreeの回転移動をおこなう。
# 直線\ellを対称軸とする対称移動をし,~~さらに点Gを中心として時計回りに90\degreeの回転移動をおこなう。
# ...
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# /var/folders/vk/q_54dbc10sxcbyt46kg46rwr0000gn/T/ipykernel_42607/2904495071.py:177: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   previous_rows = df.loc[:index - 1][df['item_id'] == item_id]
# {'success': 'JSON array exported to output.json'}

# %%
import json
import random

def split_json_array_to_files(input_file_path, training_file_path="training_set.json", test_file_path="test_set.json", split_ratio=0.7):
    """
    Reads a JSON array from a file, splits it into training and test sets, and saves them to separate files.

    Args:
        input_file_path (str): Path to the input JSON file.
        training_file_path (str): Path to save the training set JSON.
        test_file_path (str): Path to save the test set JSON.
        split_ratio (float): Ratio of training set size to total size (e.g., 0.7 for 70%).
    """
    try:
        with open(input_file_path, 'r', encoding='utf-8') as f:
            data = json.load(f)
    except FileNotFoundError:
        return {"error": f"File not found at {input_file_path}"}
    except json.JSONDecodeError:
        return {"error": f"Invalid JSON format in {input_file_path}"}
    except Exception as e:
        return {"error": f"An unexpected error occurred reading the JSON file: {e}"}

    # random.shuffle(data)  # Shuffle the data to ensure random split

    split_index = int(len(data) * split_ratio)
    training_set = data[:split_index]
    test_set = data[split_index:]

    try:
        with open(training_file_path, 'w', encoding='utf-8') as f:
            json.dump(training_set, f, ensure_ascii=False, indent=4)

        with open(test_file_path, 'w', encoding='utf-8') as f:
            json.dump(test_set, f, ensure_ascii=False, indent=4)

        return {"success": f"JSON array split and saved to {training_file_path} and {test_file_path}"}

    except Exception as e:
        return {"error": f"An error occurred writing to JSON files: {e}"}

# %%
input_file_path = "output.json"
split_json_array_to_files(input_file_path)
# Out:
# {'success': 'JSON array split and saved to training_set.json and test_set.json'}
